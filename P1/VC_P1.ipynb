# %% [markdown]
# Paquetes necesarios

# %%
import cv2  
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Inicializaciones

# %%
#Dimensiones de la imagen a crear
height = 300
width = 200

# %% [markdown]
# Imagen en grises

# %%
#Crea una imagen de un único plano
# Al ser un único plano, se interpreta como nivel de gris (0 negro, 255 blanco)
gris_img = np.zeros((height,width,1), dtype = np.uint8)
#Muestra dimensiones de la imagen creada
print(gris_img.shape)
# Out:
# (200, 300, 1)

# %% [markdown]
# Muestra imagen con imshow (OpenCV) en ventana independiente

# %%
#Muestra la imagen (negra al inicializarse a 0) con las utilidades de OpenCV en una ventana independiente
cv2.imshow('Imagen', gris_img)

cv2.waitKey(-1) # Se detiene hasta pulsar tecla (>0 milisegundos)
cv2.destroyAllWindows() # Destruye todas las ventanas

# %% [markdown]
# Muestra imagen con matplotlib

# %%
#Muestra la imagen con matplotlib, aparece integrada en el cuaderno
#Es necesario especificar que el mapa de color usado es de grises
plt.imshow(gris_img, cmap='gray') #default: 'viridis'
#plt.imshow(gris_img)
plt.show()

#replicar una imagen de gris creando una imagen gris pero con tres planos (RGB)
#img2 = cv2.merge((gris_img,gris_img,gris_img))
#plt.imshow(img2)
#plt.show()

# %% [markdown]
# Imagen con tono de gris aleatorio

# %%
#Crea imagen con un único plano (gris)

height = 300
width = 200
gris_img = np.random.randint(255, size=(height,width, 1))
#Muestra dimensiones
print(gris_img.shape)
#Visualiza
plt.imshow(gris_img, cmap='Blues') #Visualiza con mapa de color gris
plt.show()
# Out:
# (300, 200, 1)

# %% [markdown]
# Asignamos valor a los píxeles de una zona concreta

# %%
gris_img = np.zeros((height,width,1), dtype = np.uint8)
#Modifica un par de zonas rectangulares de la imagen
gris_img[10:20,0:width,0] = 255 #tercer índice especifica un canal (0-2)
#gris_img[110:220,0:20,0] = 28 #
#gris_img[50:70,40:60] = 255 #realmente no es necesario especificar el plano con un único plano

#Muestra la imagen con matplotlib
#Al ser un plano, recordar especificar que el mapa de color usado es de grises
plt.imshow(gris_img, cmap='gray') #Te animo a probar a eliminar la especificación del mapa de color
plt.show()

# %% [markdown]
# TAREA: Crea una imagen, p.e. de 800x800 píxeles, con la textura del tablero de ajedrez

# %%
# Size of the chessboard
width = 800
height = 800

# Number of squares
n_squares = 8

# Size of the square
square_size = width // n_squares

# Create a single-plane image (white)
chessboard = np.ones((height, width), dtype=np.uint8) * 255

# Draw black squares in even positions: (0,0) (2,0) (4,0) (6,0) (8,0)
for i in range(0, height, square_size):
    for j in range(0, width, square_size):
        if (i // square_size + j // square_size) % 2 == 0:
            chessboard[i:i+square_size, j:j+square_size] = 0

# Show the image
plt.imshow(chessboard, cmap='gray')
plt.axis('off')  # Hide the axes
plt.show()

# %% [markdown]
# Imagen en color

# %%
height = 300
width = 200
n_channels = 3  

#Crea una imagen con tres planos
color_img = np.zeros((height,width,n_channels), dtype = np.uint8)

#Dimensiones
print(color_img.shape)
#Visualiza con matplotlib (sin especificar el mapa de color gris)
plt.imshow(color_img) 
plt.show()
# Out:
# (300, 200, 3)

# %% [markdown]
# TAREA: Crear una imagen estilo Mondrian (un ejemplo https://www3.gobiernodecanarias.org/medusa/ecoescuela/sa/2017/04/17/descubriendo-a-mondrian/ )

# %%
#Tarea: Imagen de Mondrian
width = 800
height = 800
n_channels = 3

# Create a blank image with three channels
mondrian_img = np.zeros((width,height,n_channels), dtype = np.uint8)

# We can set the color of the image by setting the values of the pixels in each channel
# mondrian_img[:,:,0] = 0 #Channel 0 is red 
# mondrian_img[:,:,1] = 0 #Channel 1 is green
# mondrian_img[:,:,2] = 0 #Channel 2 is blue

# We can also set the color of the image by setting the values of the pixels in each channel
# Blue: (0,0,255)
# Green: (0,255,0)
# Red: (255,0,0)
# White: (255,255,255)
# Yellow: (255,255,0)
# Blue: (0,0,255)

cv2.rectangle(mondrian_img, (0,0), (200,200), (255,255,0), -1) # yellow
cv2.rectangle(mondrian_img, (200,0), (400,200), (0,0,255), -1) # blue
cv2.rectangle(mondrian_img, (400,0), (600,200), (255,0,0), -1) # red
cv2.rectangle(mondrian_img, (600,0), (800,200), (255,255,255), -1) # white

plt.imshow(mondrian_img) 
plt.show()

# %%
#Tarea: Imagen de Mondrian
width = 800
height = 600

n_channels = 3

rectangle_size = 200

# Create a blank image with three channels
mondrian_img = np.zeros((height,width,n_channels), dtype = np.uint8)

# We can set the color of the image by setting the values of the pixels in each channel
# mondrian_img[:,:,0] = 0 #Channel 0 is red 
# mondrian_img[:,:,1] = 0 #Channel 1 is green
# mondrian_img[:,:,2] = 0 #Channel 2 is blue

# We can also set the color of the image by setting the values of the pixels in each channel
blue = (0,0,255)
red = (255,0,0)
white = (255,255,255)
yellow = (255,255,0)
black = (0,0,0)

# cv2.rectangle(mondrian_img, (0,0), (200,200), (255,255,0), -1) # yellow
# cv2.rectangle(mondrian_img, (200,0), (400,200), (0,0,255), -1) # blue
# cv2.rectangle(mondrian_img, (400,0), (600,200), (255,0,0), -1) # red
# cv2.rectangle(mondrian_img, (600,0), (800,200), (255,255,255), -1) # white

mondrian_rectangles = [
    [(0, 0, 200, 200, yellow),
     (200, 0, 400, 200, blue),
     (400, 0, 800, 200, white)],
    [(0, 200, 300, 400, red),
     (300, 200, 800, 400, yellow)],
    [(0, 400, 800, 550, blue)],
    [(0, 550, 100, 600, white)],
    [(100, 550, 600, 600, yellow)],
    [(600, 550, 800, 600, red)]
]

thickness = 30

for row in mondrian_rectangles:
    for rect in row:
        cv2.rectangle(mondrian_img, (rect[0], rect[1]), (rect[2], rect[3]), black, thickness)
        cv2.rectangle(mondrian_img, (rect[0], rect[1]), (rect[2], rect[3]), rect[4], -1)

plt.imshow(mondrian_img) 
plt.axis('off')
plt.show()

# %% [markdown]
# Funciones de dibujo.
# OpenCV dispone de funciones específicas para dibujar formas básicas (más información https://docs.opencv.org/4.x/dc/da5/tutorial_py_drawing_functions.html )

# %%
#Crea una imagen con tres planos
height = 300
width = 200
n_channels = 3

color_img = np.zeros((height,width,n_channels), dtype = np.uint8)

#Línea roja vertical de grosor 3
cv2.line(color_img,(int(width/2),0),(int(width/2),height),(255,0,0),3)

#Rectángulo con grosor 2
cv2.rectangle(color_img,(10,10),(width-10,int(height/2)),(0,255,0),2)

#Rectángulo relleno
cv2.rectangle(color_img,(20,20),(60,40),(0,255,0),-1)

#Círculo de radio 15 relleno
cv2.circle(color_img,(width-60,30), 15, (0,0,255), -1)

#Visualiza sin especificar el mapa de color gris
plt.imshow(color_img) 
plt.show()

#Salva la imagen resultante a disco
cv2.imwrite('imagen.jpg', color_img)
# Out:
# True

# %%
# Size of the chessboard
width = 800
height = 800
square_size = 100

# Create a single-plane image (white)
chessboard = np.ones((height, width, n_channels), dtype=np.uint8) * 255

cv2.rectangle(chessboard, (0,0), (width,height), (1,1,1), 10)

for i in range(0, width, square_size):
    for j in range(0, height, square_size):
        if (i // square_size + j // square_size) % 2 == 0:
            cv2.rectangle(chessboard, (j,i), (j+square_size, i+square_size), (240, 217, 181), -1)
        else:
            cv2.rectangle(chessboard, (j,i), (j+square_size, i+square_size), (181, 136, 99), -1)

# Show the image
plt.imshow(chessboard)
plt.axis('off')  # Hide the axes
plt.show()

# %% [markdown]
# TAREA: Resuelve una de las tareas previas (a elegir) con las funciones de dibujo de OpenCV  :)

# %%
# Size of the chessboard
width = 1100
height = 1100
n_channels = 3
n_squares = 8
thickness = 100
square_size = 125
inital_offset = 50

# Create a single-plane image (white)
chessboard = np.ones((height, width, n_channels), dtype=np.uint8) * 255

cv2.rectangle(chessboard, (0,0), (width,height), (141,73,37), thickness)

for i in range(0, 1000, square_size):
    for j in range(0, 1000, square_size):
        if (i // square_size + j // square_size) % 2 == 0:
            cv2.rectangle(chessboard, (j+inital_offset,i+inital_offset), (j+square_size+inital_offset, i+square_size+inital_offset), (0,0,0), -1)


# Show the image
plt.imshow(chessboard)
plt.axis('off')  # Hide the axes
plt.show()

# %% [markdown]
# Abrir imagen almacenada en disco

# %%
#Carga imagen desde disco
img = cv2.imread('logo_ulpgc_vertical_acronimo_mancheta_azul.png') 
#Dimensiones
print(img.shape)
#Muestra
plt.imshow(img) 
plt.show()

#OpenCV lee las imágenes de disco en formato BGR, por lo que convertimos para visualizr RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb) 
plt.show()

#Fuerza lectura en grises
img = cv2.imread('logo_ulpgc_vertical_acronimo_mancheta_azul.png', cv2.IMREAD_GRAYSCALE) 
plt.imshow(img, cmap='gray') 
plt.show()
# Out:
# (1200, 1180, 3)

# %% [markdown]
# Abre un archivo de vídeo

# %%
# Abre vídeo
vid = cv2.VideoCapture('AyagauresResult.m4v') 
  
# En caso de estar abierto
if vid.isOpened():
    while(True):      
        # fotograma a fotograma
        ret, frame = vid.read()

        # Hay nuevo fotograma
        if ret:  
            # Muestra fotograma
            cv2.imshow('Vid', frame)
        
        # Detenemos pulsado ESC
        if cv2.waitKey(200) == 27:
            break
    
    # Libera el objeto de captura
    vid.release()
    # Destruye ventanas
    cv2.destroyAllWindows()

# %% [markdown]
# Muestra entrada de la cámara

# %%
vid = cv2.VideoCapture(0)
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()
  
    # Hay nuevo fotograma
    if ret:  
        # Muestra fotograma
        cv2.imshow('Vid', frame)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# 2024-09-15 01:22:32.130 python[19011:609046] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.

# %% [markdown]
# Separa los tres planos de la imagen captada por la webcam y muestra en horizontal

# %%
vid = cv2.VideoCapture(0)
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret:
        #Separamos canales
        b = frame[:,:,0]
        g = frame[:,:,1]
        r = frame[:,:,2]
        #Dimensiones imagen de entrada
        h, w, c = frame.shape

        #Concateamos en horizontal los tres planos del fotograma
        collage = np.hstack((r, g, b))
    
        # Muestra fotograma redimensionando a la mitad para que quepa en pantalla
        cv2.imshow('RGB', cv2.resize(collage, (int(w*1.5),int(h/2)),cv2.INTER_NEAREST))
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# TAREA: Modifica de forma libre los valores de un plano de la imagen

# %%
vid = cv2.VideoCapture('baptisterio.mp4')

while True:
    # frame to frame
    ret, frame = vid.read()

    if not ret:
        # If we've reached the end of the video, reset to the beginning
        vid.set(cv2.CAP_PROP_POS_FRAMES, 0)
        continue

    # get the channels. OpenCV reads the image in BGR format
    b = frame[:,:,0] # blue channel
    g = frame[:,:,1] # green channel
    r = frame[:,:,2] # red channel
    
    b_increased = b + 100
    g_increased = g + 100
    r_increased = r + 100
    
    # altered frame with increased red channel
    altered_frame_b = frame.copy()
    altered_frame_g = frame.copy()
    altered_frame_r = frame.copy()

    altered_frame_b[:,:,0] = b_increased
    altered_frame_g[:,:,1] = g_increased
    altered_frame_r[:,:,2] = r_increased

    sepia_filter = np.array([[0.272, 0.534, 0.131],
                             [0.349, 0.686, 0.168],
                             [0.393, 0.769, 0.189]])

    # apply the sepia filter to the image
    sepia_frame = cv2.transform(frame, sepia_filter)

    # apply the sepia filter to the image
    sepia_frame = cv2.transform(frame, sepia_filter)

    # concatenate the altered frames and the sepia frame in 4x4 
    # Create a 4x4 collage
    top_row = np.hstack((altered_frame_b, altered_frame_g))
    bottom_row = np.hstack((altered_frame_r, sepia_frame))
    collage = np.vstack((top_row, bottom_row))

    # show the result image
    cv2.imshow('Cam', collage)

    # stop the video when the ESC key is pressed
    if cv2.waitKey(20) == 27:
        plt.imshow(collage)
        plt.axis('off')
        plt.show()
        break

# release the video capture object
vid.release()
# destroy the windows
cv2.destroyAllWindows()
# Out:
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.

# %% [markdown]
# Evento de ratón para mostrar el valor RGB del píxel

# %%
# Función que trata eventos de ratón 
def mouse_events(event, x, y, flags, params):
    global px, py, R, G, B
    px = -1
    # Movimiento del puntero     
    if event==cv2.EVENT_MOUSEMOVE:
        #Valores del píxel, desde la webcam no es BGR
        B = frame[y, x, 0]
        G = frame[y, x, 1]
        R = frame[y, x, 2]  
        # Almacena valores del evento
        px = x
        py = y

# %%
vid = cv2.VideoCapture(0)

# Tipografía para mostrar texto
font = cv2.FONT_HERSHEY_SIMPLEX
  
lanzado = 0 #bandera para primer fotograma
px = -1

while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret: 
        # Activa el manejador en el primer fotograma
        if lanzado == 0:
            # Muestra fotograma
            cv2.imshow('Cam', frame)   
            # Define el nombre del manejador del evento
            cv2.setMouseCallback('Cam', mouse_events)
            lanzado = 1
            
        # Muestra valores RGB intentando centrar en el puntero
        if px > -1:
            cv2.putText(frame, '{}'.format(R), (px-45,py-5), font, 0.5, (0, 0, 255), 1)
            cv2.putText(frame, '     {}'.format(G), (px-54,py-5), font, 0.5, (0, 255, 0), 1)
            cv2.putText(frame, '         {}'.format(B), (px-54,py-5), font, 0.5, (255, 0, 0), 1)
            
        cv2.imshow('Cam', frame)   
        
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# TAREA:
# Pintar círculos en las posiciones del píxel más claro y oscuro de la imagen
# ¿Si quisieras hacerlo sobre la zona 8x8 más clara/oscura?

# %%
import cv2
import numpy as np

vid = cv2.VideoCapture(0)
font = cv2.FONT_HERSHEY_SIMPLEX

while(True):
    ret, frame = vid.read()
    if ret:
        # Convert frame to grayscale
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
                
        # Find the darkest pixel
        min_val = np.min(gray)
        min_loc_index = np.argmin(gray)
        min_loc = np.unravel_index(min_loc_index, gray.shape)
        
        # Find the brightest pixel
        max_val = np.max(gray)
        max_loc_index = np.argmax(gray)
        max_loc = np.unravel_index(max_loc_index, gray.shape)
        
        # Mark the darkest pixel
        cv2.circle(frame, (min_loc[1], min_loc[0]), 5, (255, 0, 0), 2)  # Blue circle
        
        # Mark the brightest pixel
        cv2.circle(frame, (max_loc[1], max_loc[0]), 5, (0, 0, 255), 2)  # Red circle
        
        # Display the frame
        cv2.imshow('Cam', frame)
        
    if cv2.waitKey(20) == 27:
        break

vid.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Initialize variables
vid = cv2.VideoCapture('AyagauresResult.m4v')
font = cv2.FONT_HERSHEY_SIMPLEX
initial_frame = None

while(True):
    ret, frame = vid.read()
    if ret:
        # Convert frame to grayscale with shape
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        # Find the darkest and brightest pixels
        min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(gray)
        
        # Mark the darkest pixel
        cv2.circle(frame, min_loc, 5, (255, 0, 0), 2)  # Blue circle
        cv2.putText(frame, 'Darkest', (min_loc[0] + 5, min_loc[1] - 5), font, 0.5, (255, 0, 0), 2)
        
        # Mark the brightest pixel
        cv2.circle(frame, max_loc, 5, (0, 0, 255), 2)  # Red circle
        cv2.putText(frame, 'Brightest', (max_loc[0] + 5, max_loc[1] - 5), font, 0.5, (0, 0, 255), 2)
        
        # Display the frame
        cv2.imshow('Cam', frame)

        if initial_frame is None:
            plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
            plt.axis('off')
            plt.show()
            initial_frame = frame
        
    if cv2.waitKey(20) == 27: 
        break

vid.release()
cv2.destroyAllWindows()

# %% [markdown]
# ¿Si quisieras hacerlo sobre la zona 8x8 más clara/oscura?

# %%
import cv2
import numpy as np

vid = cv2.VideoCapture(0)
font = cv2.FONT_HERSHEY_SIMPLEX

while(True):
    ret, frame = vid.read()
    if ret:
        # Convert frame to grayscale
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        # Initialize variables to track the brightest 8x8 zone
        max_sum = -1
        brightest_zone_top_left = (0, 0)
        
        # Slide an 8x8 window over the image
        for y in range(gray.shape[0] - 7):
            for x in range(gray.shape[1] - 7):
                # Compute the sum of pixel values within the 8x8 window
                window_sum = np.sum(gray[y:y+8, x:x+8])
                
                # Update the brightest zone if the current window has a higher sum
                if window_sum > max_sum:
                    max_sum = window_sum
                    brightest_zone_top_left = (x, y)
        
        # Mark the brightest 8x8 zone
        top_left = brightest_zone_top_left
        bottom_right = (top_left[0] + 8, top_left[1] + 8)
        cv2.rectangle(frame, top_left, bottom_right, (0, 0, 255), 2)  # Red rectangle
        
        # Display the frame
        cv2.imshow('Cam', frame)
        
    if cv2.waitKey(20) == 27:
        break

vid.release()
cv2.destroyAllWindows()

# %% [markdown]
# Pop art
# Salida de la webcam "inspirada" en Andy Warhol (Marilyn, https://temasycomentariosartepaeg.blogspot.com/p/autor-andy-warhol-1928-1987-titulo.html)

# %%
vid = cv2.VideoCapture(0)

#Dimensiones de la cámara
w = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))

#Fuerzo a mitad de resolución para ocupar menos pantalla
w=int(w/2)
h=int(h/2)
vid.set(cv2.CAP_PROP_FRAME_WIDTH, w) #En Mac no reacciona a estos comandos
vid.set(cv2.CAP_PROP_FRAME_HEIGHT, h)

#Imagen conjunta 2x original
collage = np.zeros((h*2,w*2,3), dtype = np.uint8)
tl = collage[0:h,0:w]
tr = collage[0:h,w:w+w]
bl = collage[h:h+h,0:w]
br = collage[h:h+h,w:w+w]

while True:      
    # fotograma a fotograma
    ret, frameIN = vid.read()

    #Menor tamaño
    frame = cv2.resize(frameIN, (int(w),int(h)),cv2.INTER_NEAREST)

    if ret:
        #Separamos canales
        r = frame[:,:,2]
        g = frame[:,:,1]
        b = frame[:,:,0]

        #Jugamos con los valores de los planos
        tl[:,:,0] = b
        tl[:,:,1] = g
        tl[:,:,2] = r

        tr[:,:,0] = 255 - r
        tr[:,:,1] = g
        tr[:,:,2] = b
        
        bl[:,:,0] = r
        bl[:,:,1] = 255 - b
        bl[:,:,2] = g

        br[:,:,0] = b
        br[:,:,1] = g
        br[:,:,2] = 255 - r
    
        # Muestra composición
        cv2.imshow('Cam', collage)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# Transformando la imagen capturada en una colección de círculos, cuyo radio depende de la intensidad promedio de la zona

# %%
vid = cv2.VideoCapture(0)

# Se define el número de celdas
ncells = 10
off = int(ncells/2)
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret:
        #Dimensiones originales
        h, w, c = frame.shape
        #Redimensiono teniendo en cuenta ncells
        down_frame = cv2.resize(frame, (int(w/ncells),int(h/ncells)),cv2.INTER_NEAREST)
        #Dimensiones reducidas
        h2, w2, c2 = down_frame.shape

        #Separamos canales
        r = down_frame[:,:,0]
        g = down_frame[:,:,1]
        b = down_frame[:,:,2]

        # Creamos imagen negra
        gris_up_frame = np.zeros((h2*ncells,w2*ncells,1), dtype = np.uint8)

        # recorre valores de la imagen reducida
        for y in range(0,h2):
            for x in range(0,w2):
                # La suma de los valores RGB define el radio del círculo
                rad = int ( (r[y,x] + g[y,x] + b[y,x])/(ncells*3*2))
                cv2.circle(gris_up_frame,(x*ncells+off, y*ncells + off), rad, (255,255,255), -1)

    
        # Muestra fotograma resultante
        cv2.imshow('Cam', gris_up_frame)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# /var/folders/qq/bpt2j0x16rz0xjhcf0x6w0hm0000gn/T/ipykernel_92863/531065525.py:31: RuntimeWarning: overflow encountered in scalar add
#   rad = int ( (r[y,x] + g[y,x] + b[y,x])/(ncells*3*2))

# %%
vid = cv2.VideoCapture('baptisterio.mp4')

while True:
    # frame to frame
    ret, frame = vid.read()

    if not ret:
        # If we've reached the end of the video, reset to the beginning
        vid.set(cv2.CAP_PROP_POS_FRAMES, 0)
        continue

    # Resize the frame to make it smaller
    frame = cv2.resize(frame, (frame.shape[1] // 2, frame.shape[0] // 2))

    # Create different color variations
    frame1 = frame.copy()
    frame2 = cv2.applyColorMap(frame, cv2.COLORMAP_HSV)
    frame3 = cv2.applyColorMap(frame, cv2.COLORMAP_INFERNO)
    frame4 = cv2.applyColorMap(frame, cv2.COLORMAP_DEEPGREEN)
    
    # Create a 2x2 collage
    top_row = np.hstack((frame1, frame2))
    bottom_row = np.hstack((frame3, frame4))
    collage = np.vstack((top_row, bottom_row))

    # Show the result image
    cv2.imshow('Pop Art Effect', collage)

    # Stop the video when the ESC key is pressed
    if cv2.waitKey(20) == 27:
        plt.imshow(cv2.cvtColor(collage, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.show()
        break

# Release the video capture object
vid.release()
# Destroy the windows
cv2.destroyAllWindows()

# %% [markdown]
# TAREA: Llevar a cabo una propuesta propia de pop art
