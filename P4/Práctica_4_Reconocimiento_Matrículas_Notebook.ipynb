# %% [markdown]
# # Práctica 4: Reconocimiento de Matrículas
#
# Este notebook implementa un prototipo de reconocimiento de matrículas de vehículos en video. Los objetivos de esta práctica incluyen la detección y seguimiento de personas y vehículos, el reconocimiento de matrículas visibles en los vehículos, y la exportación de los resultados en un video y un archivo CSV.

# %% [markdown]
# ## Objetivos
#
# La práctica se enfoca en desarrollar un sistema de detección y reconocimiento de objetos que cumpla con los siguientes requisitos:
#
# - Detección y seguimiento: Identificación y rastreo de personas y vehículos presentes en el video.
# - Reconocimiento de matrículas: Detección de matrículas en los vehículos y reconocimiento del texto usando OCR.
# - Conteo total de clases: Recuento acumulativo de cada tipo de objeto detectado.
# - Exportación de resultados: Generación de un video que visualice los resultados y exportación de un archivo CSV con el detalle de las detecciones.

# %% [markdown]
# ## Preparación del entorno

# %%
import cv2
import time
import math
import csv
from collections import defaultdict, Counter
from ultralytics import YOLO
import easyocr

# %%
def initialize_model(model_path):
    """Initialize the YOLO model for detection."""
    return YOLO(model_path)

def initialize_reader():
    """Initialize the EasyOCR reader."""
    return easyocr.Reader(['en'])  

def initialize_video_writer(cap, output_video_path):
    """Set up the video writer for the processed video."""
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec
    fps = cap.get(cv2.CAP_PROP_FPS)
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    return cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

def write_csv_header(csv_file_path):
    """Prepare CSV file for logging."""
    with open(csv_file_path, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['frame', 'object_type', 'confidence', 'tracking_id', 'x1', 'y1', 'x2', 'y2',
                         'license_plate_confidence', 'mx1', 'my1', 'mx2', 'my2', 'license_plate_text'])

def put_text(frame, text, position, color=(0, 255, 0), font_scale=0.6, thickness=2, bg_color=(0, 0, 0)):
    """Helper function to put text with background on the frame."""
    text_size = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, font_scale, thickness)[0]
    text_x, text_y = position
    box_coords = ((text_x, text_y - text_size[1] - 5), (text_x + text_size[0] + 5, text_y + 5))
    cv2.rectangle(frame, box_coords[0], box_coords[1], bg_color, cv2.FILLED)
    cv2.putText(frame, text, position, cv2.FONT_HERSHEY_SIMPLEX, font_scale, color, thickness)

# %%
# Parameters 
video_path = 'C0142.mp4'  # Path to input video
model_path = 'yolo11n.pt'  # Path to YOLO model
license_plate_detector_model_path = 'runs/detect/license_plate_detector/weights/best.pt'  # Path to license plate detector model
output_video_path = 'output_video.mp4'  # Path to save the annotated output video
csv_file_path = 'detection_tracking_log.csv'  # Path to save the CSV log file
show_video = True  # Set to True to display the video while processing
classes_to_detect = [0, 1, 2, 3, 5]  # Class IDs to detect (e.g., [0, 2] for person and car)

model = initialize_model(model_path)
license_plate_detector = YOLO(license_plate_detector_model_path)
reader = initialize_reader()

# Open the video file and set up output for processed video
cap = cv2.VideoCapture(video_path)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec
fps = cap.get(cv2.CAP_PROP_FPS)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = initialize_video_writer(cap, output_video_path)
write_csv_header(csv_file_path)

# Define class names and colors for display
class_names = {
    0: "person",
    1: "bicycle",
    2: "car",
    3: "motorbike",
    5: "bus"
}
class_colors = {
    0: (255, 0, 0),
    1: (0, 255, 0),
    2: (0, 0, 255),
    3: (255, 255, 0),
    5: (0, 255, 255)
}

# Persistent total count of each class across all frames
total_class_count = Counter()
# Track unique IDs for each class to count only once
seen_ids = defaultdict(set)
frame_number = 0  # Initialize frame counter

# Loop through each frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    start_time = time.time()
    frame_number += 1

    # Run YOLO detection and tracking
    results = model.track(frame, persist=True, classes=classes_to_detect)
    current_frame_count = Counter()

    # Process detections
    for result in results:
        boxes = result.boxes

        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cls = int(box.cls[0])
            confidence = round(float(box.conf[0]), 2)

            if box.id is not None:
                track_id = int(box.id[0].tolist())
                if track_id not in seen_ids[cls]:
                    seen_ids[cls].add(track_id)
                    total_class_count[class_names[cls]] += 1

                # Draw bounding box and label
                color = class_colors.get(cls, (0, 255, 0))
                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 3)
                put_text(frame, f"{class_names[cls]} {confidence}", (x1, y1 - 10), color=color)
                put_text(frame, f"ID: {track_id}", (x1, y2 + 20), color=color)

                # License plate recognition for cars
                license_plate_text = ""
                plate_confidence = None
                mx1, my1, mx2, my2 = None, None, None, None

                # Check if the detected object is a car, then detect license plate within its bounding box
                if class_names[cls] in ["car", "motorbike", "bus"]:
                    vehicle_img = frame[y1:y2, x1:x2]  # Crop the vehicle area to search for license plate
                    
                    # Check if the cropped image is large enough for license plate detection
                    min_plate_size = 100
                    if vehicle_img.shape[0] < min_plate_size or vehicle_img.shape[1] < min_plate_size:
                        continue
                    
                    # Check if the confidence is high enough for license plate detection
                    if confidence < 0.7:
                        continue
                    
                    # Run license plate detector model on the cropped vehicle image
                    plate_results = license_plate_detector.predict(vehicle_img)

                    # Process license plate detection results
                    if plate_results and len(plate_results[0].boxes) > 0:
                        for plate_box in plate_results[0].boxes:
                            # Get bounding box coordinates for the license plate, adjusted to the frame's coordinates
                            px1, py1, px2, py2 = map(int, plate_box.xyxy[0])
                            px1, py1, px2, py2 = px1 + x1, py1 + y1, px2 + x1, py2 + y1  # Adjust to the car's bounding box position
                                                        
                            # Draw bounding box for license plate
                            background_color = (255, 255, 255)  # White background for contrast
                            cv2.rectangle(frame, (px1, py1), (px2, py2), background_color, 2)
                                
                            # Extract the license plate text using OCR
                            license_plate_roi = frame[py1:py2, px1:px2]
                            plate_ocr_results = reader.readtext(license_plate_roi, allowlist='0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ')
                            
                            if plate_ocr_results:
                                license_plate_text = plate_ocr_results[0][-2]
                                plate_confidence = round(plate_ocr_results[0][-1], 2)

                                # Draw label for license plate in high-contrast format
                                high_contrast_color = (0, 0, 0)  # Black text
                                put_text(frame, f"Plate: {license_plate_text}", (px1, py2 + 20), color=high_contrast_color, bg_color=background_color)
                                
                                # Save coordinates for CSV logging
                                mx1, my1, mx2, my2 = px1, py1, px2, py2

                # Write to CSV
                with open(csv_file_path, mode='a', newline='') as file:
                    writer = csv.writer(file)
                    writer.writerow([frame_number, class_names[cls], confidence, track_id, x1, y1, x2, y2,
                                     plate_confidence, mx1, my1, mx2, my2, license_plate_text])

                current_frame_count[class_names[cls]] += 1

    # Display counts and FPS
    y_offset = 30
    for cls, count in total_class_count.items():
        put_text(frame, f"Total {cls}: {count}", (10, y_offset))
        y_offset += 20

    for cls, count in current_frame_count.items():
        put_text(frame, f"Frame {cls}: {count}", (10, y_offset), color=(255, 0, 0))
        y_offset += 20

    fps_calc = 1.0 / (time.time() - start_time)
    put_text(frame, f"FPS: {fps_calc:.2f}", (10, y_offset), color=(255, 0, 0))

    # Write frame to output video
    out.write(frame)

    # Optionally display the frame
    if show_video:
        cv2.imshow('Detection and Tracking', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 car, 1 bus, 37.0ms
# Speed: 1.6ms preprocess, 37.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 37.9ms
# Speed: 1.7ms preprocess, 37.9ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 28.4ms
# Speed: 1.5ms preprocess, 28.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 109.2ms
# Speed: 1.6ms preprocess, 109.2ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 33.5ms
# Speed: 1.6ms preprocess, 33.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 37.1ms
# Speed: 1.4ms preprocess, 37.1ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 28.7ms
# Speed: 1.4ms preprocess, 28.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 75.2ms
# Speed: 1.4ms preprocess, 75.2ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 37.8ms
# Speed: 2.1ms preprocess, 37.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 47.3ms
# Speed: 1.3ms preprocess, 47.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 32.7ms
# Speed: 1.5ms preprocess, 32.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 34.1ms
# Speed: 10.5ms preprocess, 34.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 67.8ms
# Speed: 1.9ms preprocess, 67.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 27.8ms
# Speed: 2.1ms preprocess, 27.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 32.7ms
# Speed: 1.7ms preprocess, 32.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 28.6ms
# Speed: 1.4ms preprocess, 28.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 (no detections), 46.8ms
# Speed: 9.4ms preprocess, 46.8ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 30.2ms
# Speed: 1.4ms preprocess, 30.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 39.2ms
# Speed: 1.2ms preprocess, 39.2ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 61.2ms
# Speed: 12.3ms preprocess, 61.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 38.3ms
# Speed: 1.2ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 35.0ms
# Speed: 2.4ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 30.4ms
# Speed: 2.0ms preprocess, 30.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 29.8ms
# Speed: 1.2ms preprocess, 29.8ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 28.0ms
# Speed: 1.5ms preprocess, 28.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 31.6ms
# Speed: 4.9ms preprocess, 31.6ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 40.6ms
# Speed: 1.8ms preprocess, 40.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 31.7ms
# Speed: 1.9ms preprocess, 31.7ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 26.6ms
# Speed: 1.4ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 27.8ms
# Speed: 1.2ms preprocess, 27.8ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 28.5ms
# Speed: 1.5ms preprocess, 28.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 31.2ms
# Speed: 2.8ms preprocess, 31.2ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 38.4ms
# Speed: 1.7ms preprocess, 38.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 82.3ms
# Speed: 1.4ms preprocess, 82.3ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 28.4ms
# Speed: 2.5ms preprocess, 28.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 Licenseplate, 31.6ms
# Speed: 1.5ms preprocess, 31.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 54.4ms
# Speed: 1.4ms preprocess, 54.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 Licenseplate, 33.8ms
# Speed: 6.9ms preprocess, 33.8ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 27.5ms
# Speed: 1.8ms preprocess, 27.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 Licenseplate, 32.1ms
# Speed: 1.3ms preprocess, 32.1ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 42.3ms
# Speed: 1.5ms preprocess, 42.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 Licenseplate, 95.3ms
# Speed: 1.5ms preprocess, 95.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 30.3ms
# Speed: 1.9ms preprocess, 30.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 95.5ms
# Speed: 16.2ms preprocess, 95.5ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 39.2ms
# Speed: 1.8ms preprocess, 39.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 41.4ms
# Speed: 1.4ms preprocess, 41.4ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 63.0ms
# Speed: 1.8ms preprocess, 63.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 Licenseplate, 32.9ms
# Speed: 1.3ms preprocess, 32.9ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 30.5ms
# Speed: 31.7ms preprocess, 30.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 31.6ms
# Speed: 1.8ms preprocess, 31.6ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 44.0ms
# Speed: 2.1ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 37.8ms
# Speed: 19.2ms preprocess, 37.8ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 30.4ms
# Speed: 1.5ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 36.6ms
# Speed: 1.5ms preprocess, 36.6ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 26.8ms
# Speed: 2.1ms preprocess, 26.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 79.9ms
# Speed: 1.5ms preprocess, 79.9ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 43.6ms
# Speed: 2.0ms preprocess, 43.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 155.4ms
# Speed: 1.4ms preprocess, 155.4ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 42.2ms
# Speed: 1.5ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 35.5ms
# Speed: 1.4ms preprocess, 35.5ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 31.3ms
# Speed: 2.1ms preprocess, 31.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 56.7ms
# Speed: 1.6ms preprocess, 56.7ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 27.8ms
# Speed: 1.7ms preprocess, 27.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 28.0ms
# Speed: 1.4ms preprocess, 28.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 70.1ms
# Speed: 10.2ms preprocess, 70.1ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 32.5ms
# Speed: 2.0ms preprocess, 32.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 45.8ms
# Speed: 1.3ms preprocess, 45.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 45.8ms
# Speed: 1.5ms preprocess, 45.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 61.1ms
# Speed: 2.6ms preprocess, 61.1ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 26.7ms
# Speed: 1.5ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 66.0ms
# Speed: 1.4ms preprocess, 66.0ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 29.3ms
# Speed: 1.6ms preprocess, 29.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 36.5ms
# Speed: 1.5ms preprocess, 36.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 64.7ms
# Speed: 1.6ms preprocess, 64.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 47.5ms
# Speed: 2.0ms preprocess, 47.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 42.7ms
# Speed: 24.0ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 38.6ms
# Speed: 1.8ms preprocess, 38.6ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 38.0ms
# Speed: 1.5ms preprocess, 38.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 46.1ms
# Speed: 1.4ms preprocess, 46.1ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 58.1ms
# Speed: 2.1ms preprocess, 58.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 52.1ms
# Speed: 1.5ms preprocess, 52.1ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 40.3ms
# Speed: 3.3ms preprocess, 40.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 38.7ms
# Speed: 1.7ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 40.9ms
# Speed: 1.6ms preprocess, 40.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 48.3ms
# Speed: 3.2ms preprocess, 48.3ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 33.1ms
# Speed: 1.8ms preprocess, 33.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 42.6ms
# Speed: 2.2ms preprocess, 42.6ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 27.1ms
# Speed: 1.6ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 1 Licenseplate, 39.0ms
# Speed: 8.6ms preprocess, 39.0ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 29.5ms
# Speed: 6.9ms preprocess, 29.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 40.8ms
# Speed: 1.3ms preprocess, 40.8ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 48.6ms
# Speed: 1.7ms preprocess, 48.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 80.7ms
# Speed: 1.5ms preprocess, 80.7ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 39.7ms
# Speed: 2.1ms preprocess, 39.7ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 32.9ms
# Speed: 5.4ms preprocess, 32.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 1 Licenseplate, 36.9ms
# Speed: 1.2ms preprocess, 36.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 37.3ms
# Speed: 6.7ms preprocess, 37.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 37.7ms
# Speed: 1.3ms preprocess, 37.7ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 34.4ms
# Speed: 1.6ms preprocess, 34.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 48.8ms
# Speed: 2.2ms preprocess, 48.8ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 31.5ms
# Speed: 2.4ms preprocess, 31.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 36.1ms
# Speed: 1.3ms preprocess, 36.1ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 26.0ms
# Speed: 1.8ms preprocess, 26.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 65.6ms
# Speed: 1.8ms preprocess, 65.6ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 37.6ms
# Speed: 2.8ms preprocess, 37.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 1 Licenseplate, 50.9ms
# Speed: 1.6ms preprocess, 50.9ms inference, 0.4ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 36.7ms
# Speed: 2.2ms preprocess, 36.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 83.3ms
# Speed: 1.5ms preprocess, 83.3ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 27.3ms
# Speed: 1.4ms preprocess, 27.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 43.0ms
# Speed: 2.0ms preprocess, 43.0ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 32.7ms
# Speed: 1.8ms preprocess, 32.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 42.0ms
# Speed: 1.2ms preprocess, 42.0ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 28.6ms
# Speed: 1.6ms preprocess, 28.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 38.0ms
# Speed: 1.2ms preprocess, 38.0ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 31.4ms
# Speed: 1.8ms preprocess, 31.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 36.9ms
# Speed: 1.3ms preprocess, 36.9ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 29.5ms
# Speed: 1.3ms preprocess, 29.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 47.9ms
# Speed: 1.8ms preprocess, 47.9ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 62.2ms
# Speed: 1.7ms preprocess, 62.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 71.5ms
# Speed: 1.6ms preprocess, 71.5ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 81.2ms
# Speed: 1.7ms preprocess, 81.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 51.2ms
# Speed: 1.5ms preprocess, 51.2ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 37.0ms
# Speed: 3.7ms preprocess, 37.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 51.1ms
# Speed: 1.6ms preprocess, 51.1ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 28.2ms
# Speed: 3.6ms preprocess, 28.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 60.9ms
# Speed: 2.3ms preprocess, 60.9ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 28.1ms
# Speed: 1.5ms preprocess, 28.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 45.8ms
# Speed: 1.9ms preprocess, 45.8ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 37.4ms
# Speed: 11.5ms preprocess, 37.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 57.3ms
# Speed: 1.9ms preprocess, 57.3ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 37.2ms
# Speed: 2.8ms preprocess, 37.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 54.1ms
# Speed: 1.6ms preprocess, 54.1ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 37.3ms
# Speed: 2.0ms preprocess, 37.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 47.2ms
# Speed: 1.8ms preprocess, 47.2ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 27.0ms
# Speed: 1.5ms preprocess, 27.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 28.5ms
# Speed: 1.5ms preprocess, 28.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 39.7ms
# Speed: 2.0ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 37.5ms
# Speed: 1.4ms preprocess, 37.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 67.5ms
# Speed: 1.3ms preprocess, 67.5ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 27.4ms
# Speed: 1.4ms preprocess, 27.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 40.7ms
# Speed: 1.2ms preprocess, 40.7ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 48.0ms
# Speed: 2.1ms preprocess, 48.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 47.2ms
# Speed: 1.5ms preprocess, 47.2ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 36.1ms
# Speed: 2.3ms preprocess, 36.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 73.6ms
# Speed: 1.5ms preprocess, 73.6ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 62.0ms
# Speed: 13.1ms preprocess, 62.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 63.2ms
# Speed: 1.5ms preprocess, 63.2ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 29.4ms
# Speed: 1.4ms preprocess, 29.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 73.3ms
# Speed: 1.3ms preprocess, 73.3ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 25.7ms
# Speed: 1.6ms preprocess, 25.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 63.7ms
# Speed: 1.5ms preprocess, 63.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 36.5ms
# Speed: 1.4ms preprocess, 36.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 44.9ms
# Speed: 1.4ms preprocess, 44.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 51.5ms
# Speed: 1.6ms preprocess, 51.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 car, 1 bus, 30.4ms
# Speed: 4.6ms preprocess, 30.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 61.8ms
# Speed: 1.8ms preprocess, 61.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 car, 1 bus, 45.9ms
# Speed: 1.5ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 40.9ms
# Speed: 1.6ms preprocess, 40.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 car, 1 bus, 28.0ms
# Speed: 1.6ms preprocess, 28.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 45.3ms
# Speed: 2.1ms preprocess, 45.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 car, 1 bus, 29.9ms
# Speed: 1.4ms preprocess, 29.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 37.9ms
# Speed: 3.1ms preprocess, 37.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 car, 1 bus, 25.7ms
# Speed: 1.6ms preprocess, 25.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 32.0ms
# Speed: 1.8ms preprocess, 32.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 26.3ms
# Speed: 2.7ms preprocess, 26.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 25.9ms
# Speed: 1.5ms preprocess, 25.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 25.8ms
# Speed: 2.0ms preprocess, 25.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 55.9ms
# Speed: 2.7ms preprocess, 55.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 46.4ms
# Speed: 2.0ms preprocess, 46.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 53.4ms
# Speed: 1.8ms preprocess, 53.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 44.4ms
# Speed: 2.0ms preprocess, 44.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 32.8ms
# Speed: 1.9ms preprocess, 32.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 32.3ms
# Speed: 2.0ms preprocess, 32.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 33.9ms
# Speed: 4.8ms preprocess, 33.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.2ms
# Speed: 1.8ms preprocess, 34.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 64.1ms
# Speed: 1.3ms preprocess, 64.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 42.6ms
# Speed: 1.8ms preprocess, 42.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 63.4ms
# Speed: 16.6ms preprocess, 63.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 41.8ms
# Speed: 1.7ms preprocess, 41.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 80.4ms
# Speed: 2.4ms preprocess, 80.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 28.4ms
# Speed: 1.4ms preprocess, 28.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 49.4ms
# Speed: 3.3ms preprocess, 49.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 30.6ms
# Speed: 2.8ms preprocess, 30.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 36.1ms
# Speed: 1.6ms preprocess, 36.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 139.1ms
# Speed: 9.3ms preprocess, 139.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 38.3ms
# Speed: 8.1ms preprocess, 38.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 79.7ms
# Speed: 3.8ms preprocess, 79.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 36.1ms
# Speed: 1.7ms preprocess, 36.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 37.6ms
# Speed: 2.6ms preprocess, 37.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 3 Licenseplates, 49.6ms
# Speed: 1.8ms preprocess, 49.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 36.4ms
# Speed: 1.5ms preprocess, 36.4ms inference, 10.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 2 Licenseplates, 87.7ms
# Speed: 3.0ms preprocess, 87.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 58.9ms
# Speed: 4.4ms preprocess, 58.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 29.5ms
# Speed: 3.0ms preprocess, 29.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 33.9ms
# Speed: 1.5ms preprocess, 33.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 44.8ms
# Speed: 3.0ms preprocess, 44.8ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 42.7ms
# Speed: 3.9ms preprocess, 42.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 2 Licenseplates, 65.5ms
# Speed: 1.5ms preprocess, 65.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 73.9ms
# Speed: 5.0ms preprocess, 73.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 29.7ms
# Speed: 2.0ms preprocess, 29.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 28.1ms
# Speed: 1.7ms preprocess, 28.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 28.8ms
# Speed: 3.4ms preprocess, 28.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 27.5ms
# Speed: 1.4ms preprocess, 27.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 30.9ms
# Speed: 2.5ms preprocess, 30.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 25.0ms
# Speed: 1.5ms preprocess, 25.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 66.4ms
# Speed: 1.6ms preprocess, 66.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 29.1ms
# Speed: 2.6ms preprocess, 29.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.1ms
# Speed: 1.6ms preprocess, 34.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 49.7ms
# Speed: 1.7ms preprocess, 49.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 47.2ms
# Speed: 1.5ms preprocess, 47.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 32.4ms
# Speed: 10.7ms preprocess, 32.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 26.4ms
# Speed: 2.3ms preprocess, 26.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 68.0ms
# Speed: 2.6ms preprocess, 68.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 25.9ms
# Speed: 2.1ms preprocess, 25.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 58.3ms
# Speed: 1.6ms preprocess, 58.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 70.0ms
# Speed: 1.9ms preprocess, 70.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 59.2ms
# Speed: 2.5ms preprocess, 59.2ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 64.3ms
# Speed: 1.8ms preprocess, 64.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 50.3ms
# Speed: 3.9ms preprocess, 50.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 69.4ms
# Speed: 17.9ms preprocess, 69.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 30.3ms
# Speed: 1.6ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 30.7ms
# Speed: 1.5ms preprocess, 30.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 41.0ms
# Speed: 1.4ms preprocess, 41.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 32.5ms
# Speed: 1.9ms preprocess, 32.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 78.2ms
# Speed: 1.5ms preprocess, 78.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.9ms
# Speed: 1.5ms preprocess, 34.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 37.3ms
# Speed: 1.6ms preprocess, 37.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 69.6ms
# Speed: 1.7ms preprocess, 69.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 59.8ms
# Speed: 4.8ms preprocess, 59.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 26.3ms
# Speed: 3.8ms preprocess, 26.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.1ms
# Speed: 4.4ms preprocess, 34.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 30.1ms
# Speed: 3.0ms preprocess, 30.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 55.0ms
# Speed: 1.4ms preprocess, 55.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 42.3ms
# Speed: 2.4ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 77.6ms
# Speed: 1.5ms preprocess, 77.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.1ms
# Speed: 2.6ms preprocess, 34.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 27.6ms
# Speed: 2.1ms preprocess, 27.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 45.6ms
# Speed: 1.5ms preprocess, 45.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 35.6ms
# Speed: 1.6ms preprocess, 35.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 40.0ms
# Speed: 1.6ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 43.5ms
# Speed: 3.7ms preprocess, 43.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 43.2ms
# Speed: 1.4ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 27.0ms
# Speed: 2.5ms preprocess, 27.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 26.7ms
# Speed: 1.5ms preprocess, 26.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 54.9ms
# Speed: 1.3ms preprocess, 54.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 26.4ms
# Speed: 4.0ms preprocess, 26.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 46.5ms
# Speed: 1.5ms preprocess, 46.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 31.4ms
# Speed: 1.4ms preprocess, 31.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 56.7ms
# Speed: 4.4ms preprocess, 56.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 65.4ms
# Speed: 1.5ms preprocess, 65.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 71.4ms
# Speed: 1.4ms preprocess, 71.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 38.4ms
# Speed: 1.8ms preprocess, 38.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 1 Licenseplate, 42.1ms
# Speed: 1.9ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 29.1ms
# Speed: 2.1ms preprocess, 29.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 2 Licenseplates, 55.8ms
# Speed: 1.4ms preprocess, 55.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 56.3ms
# Speed: 1.9ms preprocess, 56.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 46.8ms
# Speed: 4.1ms preprocess, 46.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 64.1ms
# Speed: 1.7ms preprocess, 64.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 46.9ms
# Speed: 1.4ms preprocess, 46.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 57.0ms
# Speed: 2.2ms preprocess, 57.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 55.8ms
# Speed: 1.6ms preprocess, 55.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 53.8ms
# Speed: 2.4ms preprocess, 53.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 57.4ms
# Speed: 4.4ms preprocess, 57.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 39.7ms
# Speed: 3.4ms preprocess, 39.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 42.3ms
# Speed: 1.3ms preprocess, 42.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 32.0ms
# Speed: 1.6ms preprocess, 32.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 66.1ms
# Speed: 1.5ms preprocess, 66.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 32.9ms
# Speed: 1.6ms preprocess, 32.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 39.5ms
# Speed: 3.5ms preprocess, 39.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 29.3ms
# Speed: 1.5ms preprocess, 29.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 55.1ms
# Speed: 1.2ms preprocess, 55.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 27.0ms
# Speed: 1.5ms preprocess, 27.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 47.3ms
# Speed: 1.6ms preprocess, 47.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 36.0ms
# Speed: 1.6ms preprocess, 36.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 72.4ms
# Speed: 1.4ms preprocess, 72.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.0ms
# Speed: 1.6ms preprocess, 34.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 64.4ms
# Speed: 1.3ms preprocess, 64.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 28.8ms
# Speed: 2.8ms preprocess, 28.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 42.4ms
# Speed: 3.0ms preprocess, 42.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 30.1ms
# Speed: 10.7ms preprocess, 30.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 80.6ms
# Speed: 1.9ms preprocess, 80.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 32.9ms
# Speed: 2.1ms preprocess, 32.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 76.2ms
# Speed: 4.5ms preprocess, 76.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 28.3ms
# Speed: 2.1ms preprocess, 28.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 38.4ms
# Speed: 1.8ms preprocess, 38.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 90.6ms
# Speed: 1.6ms preprocess, 90.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 54.8ms
# Speed: 6.2ms preprocess, 54.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 32.1ms
# Speed: 2.6ms preprocess, 32.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 48.1ms
# Speed: 3.9ms preprocess, 48.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 28.4ms
# Speed: 1.6ms preprocess, 28.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 52.9ms
# Speed: 1.4ms preprocess, 52.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 28.5ms
# Speed: 1.7ms preprocess, 28.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 41.8ms
# Speed: 1.4ms preprocess, 41.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 27.4ms
# Speed: 2.2ms preprocess, 27.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 59.4ms
# Speed: 1.5ms preprocess, 59.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 44.2ms
# Speed: 7.3ms preprocess, 44.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 34.9ms
# Speed: 1.4ms preprocess, 34.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 50.4ms
# Speed: 1.4ms preprocess, 50.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 66.3ms
# Speed: 10.4ms preprocess, 66.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 47.6ms
# Speed: 1.5ms preprocess, 47.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 69.6ms
# Speed: 9.8ms preprocess, 69.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 71.8ms
# Speed: 1.6ms preprocess, 71.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 31.4ms
# Speed: 1.7ms preprocess, 31.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 79.5ms
# Speed: 1.4ms preprocess, 79.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 51.6ms
# Speed: 1.4ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 35.9ms
# Speed: 1.5ms preprocess, 35.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 27.9ms
# Speed: 1.6ms preprocess, 27.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 47.9ms
# Speed: 2.0ms preprocess, 47.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 44.5ms
# Speed: 2.6ms preprocess, 44.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 68.9ms
# Speed: 3.1ms preprocess, 68.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 30.0ms
# Speed: 2.1ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 31.4ms
# Speed: 1.4ms preprocess, 31.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 24.1ms
# Speed: 5.4ms preprocess, 24.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 51.0ms
# Speed: 1.4ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 50.0ms
# Speed: 6.9ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 44.1ms
# Speed: 1.8ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 24.8ms
# Speed: 1.4ms preprocess, 24.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 32.9ms
# Speed: 2.1ms preprocess, 32.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 73.0ms
# Speed: 1.5ms preprocess, 73.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 26.6ms
# Speed: 1.4ms preprocess, 26.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 58.4ms
# Speed: 15.7ms preprocess, 58.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 31.4ms
# Speed: 2.3ms preprocess, 31.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 28.8ms
# Speed: 1.5ms preprocess, 28.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 63.4ms
# Speed: 3.6ms preprocess, 63.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 35.0ms
# Speed: 6.8ms preprocess, 35.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 49.9ms
# Speed: 2.0ms preprocess, 49.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 32.3ms
# Speed: 2.5ms preprocess, 32.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 32.7ms
# Speed: 1.6ms preprocess, 32.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 73.1ms
# Speed: 1.9ms preprocess, 73.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 43.8ms
# Speed: 10.9ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 26.1ms
# Speed: 1.4ms preprocess, 26.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 48.0ms
# Speed: 1.4ms preprocess, 48.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 37.5ms
# Speed: 2.3ms preprocess, 37.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 32.1ms
# Speed: 1.4ms preprocess, 32.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 91.7ms
# Speed: 1.6ms preprocess, 91.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 30.4ms
# Speed: 2.7ms preprocess, 30.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 24.9ms
# Speed: 2.8ms preprocess, 24.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 36.7ms
# Speed: 4.7ms preprocess, 36.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 54.5ms
# Speed: 1.6ms preprocess, 54.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 45.4ms
# Speed: 1.7ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 29.7ms
# Speed: 2.0ms preprocess, 29.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 33.1ms
# Speed: 10.5ms preprocess, 33.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 29.8ms
# Speed: 2.7ms preprocess, 29.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 56.4ms
# Speed: 4.4ms preprocess, 56.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 26.3ms
# Speed: 2.1ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 34.2ms
# Speed: 1.5ms preprocess, 34.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 40.1ms
# Speed: 2.9ms preprocess, 40.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 38.1ms
# ...
#
# 0: 544x640 (no detections), 73.2ms
# Speed: 1.6ms preprocess, 73.2ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 person, 6 cars, 65.5ms
# Speed: 2.2ms preprocess, 65.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 70.4ms
# Speed: 1.6ms preprocess, 70.4ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 person, 6 cars, 62.8ms
# Speed: 1.7ms preprocess, 62.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 58.1ms
# Speed: 1.3ms preprocess, 58.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 person, 6 cars, 37.9ms
# Speed: 1.6ms preprocess, 37.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 76.8ms
# Speed: 1.1ms preprocess, 76.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 person, 5 cars, 50.3ms
# Speed: 2.0ms preprocess, 50.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 67.0ms
# Speed: 2.4ms preprocess, 67.0ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 person, 5 cars, 42.9ms
# Speed: 2.3ms preprocess, 42.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 60.7ms
# Speed: 4.4ms preprocess, 60.7ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 person, 5 cars, 70.2ms
# Speed: 22.8ms preprocess, 70.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 49.9ms
# Speed: 1.7ms preprocess, 49.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 55.7ms
# Speed: 1.8ms preprocess, 55.7ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 person, 5 cars, 45.0ms
# Speed: 1.8ms preprocess, 45.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 70.4ms
# Speed: 2.3ms preprocess, 70.4ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 person, 5 cars, 58.9ms
# Speed: 2.1ms preprocess, 58.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 49.0ms
# Speed: 1.6ms preprocess, 49.0ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 person, 6 cars, 39.7ms
# Speed: 1.6ms preprocess, 39.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 64.1ms
# Speed: 1.6ms preprocess, 64.1ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 person, 6 cars, 41.4ms
# Speed: 2.1ms preprocess, 41.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 71.7ms
# Speed: 1.8ms preprocess, 71.7ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x448 (no detections), 70.0ms
# Speed: 1.1ms preprocess, 70.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 384x640 1 person, 6 cars, 63.2ms
# Speed: 1.6ms preprocess, 63.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x448 (no detections), 86.7ms
# Speed: 1.8ms preprocess, 86.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 448)
#
# 0: 384x640 1 bicycle, 6 cars, 41.5ms
# Speed: 1.5ms preprocess, 41.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x480 (no detections), 53.1ms
# Speed: 2.6ms preprocess, 53.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 480)
#
# 0: 384x640 1 person, 6 cars, 62.9ms
# Speed: 1.6ms preprocess, 62.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 65.7ms
# Speed: 1.8ms preprocess, 65.7ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x544 (no detections), 61.8ms
# Speed: 1.5ms preprocess, 61.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 384x640 1 person, 6 cars, 38.6ms
# Speed: 2.2ms preprocess, 38.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 56.1ms
# Speed: 2.0ms preprocess, 56.1ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x576 (no detections), 61.9ms
# Speed: 2.4ms preprocess, 61.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 384x640 1 person, 6 cars, 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 67.6ms
# Speed: 1.9ms preprocess, 67.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x608 (no detections), 73.4ms
# Speed: 2.0ms preprocess, 73.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 384x640 1 person, 6 cars, 44.1ms
# Speed: 1.6ms preprocess, 44.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 85.1ms
# Speed: 2.1ms preprocess, 85.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 157.8ms
# Speed: 1.6ms preprocess, 157.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 62.2ms
# Speed: 1.9ms preprocess, 62.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 608x640 (no detections), 73.5ms
# Speed: 1.7ms preprocess, 73.5ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 person, 6 cars, 44.0ms
# Speed: 19.3ms preprocess, 44.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 62.7ms
# Speed: 1.7ms preprocess, 62.7ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 544x640 (no detections), 55.5ms
# Speed: 1.6ms preprocess, 55.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 person, 6 cars, 52.5ms
# Speed: 1.8ms preprocess, 52.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 60.9ms
# Speed: 1.8ms preprocess, 60.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 Licenseplate, 62.9ms
# Speed: 2.3ms preprocess, 62.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 person, 6 cars, 40.8ms
# Speed: 1.6ms preprocess, 40.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 Licenseplate, 53.9ms
# Speed: 2.5ms preprocess, 53.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 bicycle, 6 cars, 46.0ms
# Speed: 1.7ms preprocess, 46.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 (no detections), 60.4ms
# Speed: 1.5ms preprocess, 60.4ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 person, 6 cars, 37.1ms
# Speed: 2.1ms preprocess, 37.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 50.8ms
# Speed: 1.5ms preprocess, 50.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 416x640 1 Licenseplate, 43.9ms
# Speed: 1.2ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 person, 6 cars, 48.5ms
# Speed: 1.5ms preprocess, 48.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 60.6ms
# Speed: 1.5ms preprocess, 60.6ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 416x640 1 Licenseplate, 36.3ms
# Speed: 8.6ms preprocess, 36.3ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 person, 6 cars, 39.1ms
# Speed: 1.8ms preprocess, 39.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 Licenseplate, 62.2ms
# Speed: 2.0ms preprocess, 62.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 Licenseplate, 39.4ms
# Speed: 1.0ms preprocess, 39.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 53.2ms
# Speed: 4.7ms preprocess, 53.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 Licenseplate, 119.3ms
# Speed: 1.7ms preprocess, 119.3ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 Licenseplate, 42.4ms
# Speed: 4.9ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 53.2ms
# Speed: 1.5ms preprocess, 53.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 78.6ms
# Speed: 3.7ms preprocess, 78.6ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 Licenseplate, 65.2ms
# Speed: 1.2ms preprocess, 65.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 89.8ms
# Speed: 1.6ms preprocess, 89.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 52.9ms
# Speed: 1.4ms preprocess, 52.9ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 Licenseplate, 39.2ms
# Speed: 1.2ms preprocess, 39.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 37.1ms
# Speed: 1.6ms preprocess, 37.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 79.1ms
# Speed: 1.3ms preprocess, 79.1ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 Licenseplate, 37.7ms
# Speed: 1.2ms preprocess, 37.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 47.3ms
# Speed: 12.4ms preprocess, 47.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Licenseplate, 44.7ms
# Speed: 27.0ms preprocess, 44.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 45.3ms
# Speed: 14.2ms preprocess, 45.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 108.1ms
# Speed: 1.5ms preprocess, 108.1ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 Licenseplate, 38.7ms
# Speed: 1.7ms preprocess, 38.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 54.6ms
# Speed: 2.4ms preprocess, 54.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 53.7ms
# Speed: 1.4ms preprocess, 53.7ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 Licenseplate, 66.4ms
# Speed: 1.0ms preprocess, 66.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 56.4ms
# Speed: 1.7ms preprocess, 56.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 72.6ms
# Speed: 1.8ms preprocess, 72.6ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 416x640 1 Licenseplate, 82.4ms
# Speed: 1.5ms preprocess, 82.4ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 person, 6 cars, 51.8ms
# Speed: 2.0ms preprocess, 51.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 1 Licenseplate, 43.7ms
# Speed: 1.2ms preprocess, 43.7ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 person, 6 cars, 35.3ms
# Speed: 1.8ms preprocess, 35.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 88.5ms
# Speed: 2.1ms preprocess, 88.5ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 416x640 2 Licenseplates, 54.4ms
# Speed: 2.2ms preprocess, 54.4ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 person, 6 cars, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 2 Licenseplates, 50.9ms
# Speed: 1.4ms preprocess, 50.9ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 55
#      52 frame_number += 1
#      54 # Run YOLO detection and tracking
# ---> 55 results = model.track(frame, persist=True, classes=classes_to_detect)
#      56 current_frame_count = Counter()
#      58 # Process detections
#
# File ~/anaconda3/envs/VC_P1/lib/python3.11/site-packages/ultralytics/engine/model.py:601, in Model.track(self, source, stream, persist, **kwargs)
#     599 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     600 kwargs["mode"] = "track"
# --> 601 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~/anaconda3/envs/VC_P1/lib/python3.11/site-packages/ultralytics/engine/model.py:554, in Model.predict(self, source, stream, predictor, **kwargs)
#     552 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     553     self.predictor.set_prompts(prompts)
# --> 554 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/anaconda3/envs/VC_P1/lib/python3.11/site-packages/ultralytics/engine/predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/anaconda3/envs/VC_P1/lib/python3.11/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~/anaconda3/envs/VC_P1/lib/python3.11/site-packages/ultralytics/engine/predictor.py:262, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     260 with profilers[2]:
#     261     self.results = self.postprocess(preds, im, im0s)
# --> 262 self.run_callbacks("on_predict_postprocess_end")
#     264 # Visualize, save, write results
#     265 n = len(im0s)
#
# File ~/anaconda3/envs/VC_P1/lib/python3.11/site-packages/ultralytics/engine/predictor.py:399, in BasePredictor.run_callbacks(self, event)
#     397 """Runs all registered callbacks for a specific event."""
#     398 for callback in self.callbacks.get(event, []):
# --> 399     callback(self)
#
# File ~/anaconda3/envs/VC_P1/lib/python3.11/site-packages/ultralytics/trackers/track.py:80, in on_predict_postprocess_end(predictor, persist)
#      78 if len(det) == 0:
#      79     continue
# ---> 80 tracks = tracker.update(det, im0s[i])
#      81 if len(tracks) == 0:
#      82     continue
#
# File ~/anaconda3/envs/VC_P1/lib/python3.11/site-packages/ultralytics/trackers/byte_tracker.py:333, in BYTETracker.update(self, results, img)
#     331 self.multi_predict(strack_pool)
#     332 if hasattr(self, "gmc") and img is not None:
# --> 333     warp = self.gmc.apply(img, dets)
#     334     STrack.multi_gmc(strack_pool, warp)
#     335     STrack.multi_gmc(unconfirmed, warp)
#
# File ~/anaconda3/envs/VC_P1/lib/python3.11/site-packages/ultralytics/trackers/utils/gmc.py:115, in GMC.apply(self, raw_frame, detections)
#     113     return self.applyEcc(raw_frame)
#     114 elif self.method == "sparseOptFlow":
# --> 115     return self.applySparseOptFlow(raw_frame)
#     116 else:
#     117     return np.eye(2, 3)
#
# File ~/anaconda3/envs/VC_P1/lib/python3.11/site-packages/ultralytics/trackers/utils/gmc.py:333, in GMC.applySparseOptFlow(self, raw_frame)
#     330     frame = cv2.resize(frame, (width // self.downscale, height // self.downscale))
#     332 # Find the keypoints
# --> 333 keypoints = cv2.goodFeaturesToTrack(frame, mask=None, **self.feature_params)
#     335 # Handle first frame
#     336 if not self.initializedFirstFrame or self.prevKeyPoints is None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Resultados
#
# Esta sección se presentan los resultados obtenidos. Cargaremos el archivo CSV para revisar el recuento total de cada tipo de objeto detectado, así como los detalles de las detecciones de matrículas.

# %%
# Cargar el archivo CSV de resultados
import pandas as pd

results_df = pd.read_csv('detection_tracking_log.csv')
print("Resumen de detecciones por clase:")
print(results_df['object_type'].value_counts())

print("\nEjemplo de datos de detección de matrículas:")
display(results_df[results_df['object_type'] == 'car'].head())
# Out:
# Resumen de detecciones por clase:
# object_type
# car          11106
# person        2929
# bus            223
# motorbike       50
# bicycle         40
# Name: count, dtype: int64
#
# Ejemplo de datos de detección de matrículas:
#    frame object_type  confidence  tracking_id    x1   y1    x2   y2  \
# 1      1         car        0.84            2  1321  312  1398  371
# 3      2         car        0.81            2  1321  312  1397  371
# 5      3         car        0.82            2  1320  312  1395  371
# 7      4         car        0.84            2  1318  312  1395  371
# 9      5         car        0.82            2  1317  312  1394  371
#
#    license_plate_confidence  mx1  my1  mx2  my2 license_plate_text
# 1                       NaN  NaN  NaN  NaN  NaN                NaN
# 3                       NaN  NaN  NaN  NaN  NaN                NaN
# 5                       NaN  NaN  NaN  NaN  NaN                NaN
# 7                       NaN  NaN  NaN  NaN  NaN                NaN
# 9                       NaN  NaN  NaN  NaN  NaN                NaN

# %% [markdown]
# ## Conclusión
#
# En esta práctica se ha desarrollado un prototipo funcional que permite:
#
# - Detectar y seguir personas y vehículos en video.
# - Detectar y leer matrículas en vehículos mediante un modelo YOLO y OCR.
# - Exportar los resultados visuales en un video y los datos de detección en un archivo CSV.
#
# Este prototipo constituye una herramienta útil para el análisis automatizado de video en aplicaciones de monitoreo y seguridad, con posibilidad de mejoras futuras en el rendimiento y precisión del OCR de matrículas.
