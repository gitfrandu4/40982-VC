# %% [markdown]
# # Práctica 4: Reconocimiento de Matrículas
#
# Este notebook implementa un prototipo de reconocimiento de matrículas de vehículos en video. Los objetivos de esta práctica incluyen la detección y seguimiento de personas y vehículos, el reconocimiento de matrículas visibles en los vehículos, y la exportación de los resultados en un video y un archivo CSV.

# %% [markdown]
# ## Objetivos
#
# La práctica se enfoca en desarrollar un sistema de detección y reconocimiento de objetos que cumpla con los siguientes requisitos:
#
# - Detección y seguimiento: Identificación y rastreo de personas y vehículos presentes en el video.
# - Reconocimiento de matrículas: Detección de matrículas en los vehículos y reconocimiento del texto usando OCR.
# - Conteo total de clases: Recuento acumulativo de cada tipo de objeto detectado.
# - Exportación de resultados: Generación de un video que visualice los resultados y exportación de un archivo CSV con el detalle de las detecciones.

# %% [markdown]
# ## Preparación del entorno

# %%
import cv2
import time
import math
import csv
from collections import defaultdict, Counter
from ultralytics import YOLO
import easyocr

# %%
def initialize_model(model_path):
    """Initialize the YOLO model for detection."""
    return YOLO(model_path)

def initialize_reader():
    """Initialize the EasyOCR reader."""
    return easyocr.Reader(['en'])  

def initialize_video_writer(cap, output_video_path):
    """Set up the video writer for the processed video."""
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec
    fps = cap.get(cv2.CAP_PROP_FPS)
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    return cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

def write_csv_header(csv_file_path):
    """Prepare CSV file for logging."""
    with open(csv_file_path, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['frame', 'object_type', 'confidence', 'tracking_id', 'x1', 'y1', 'x2', 'y2',
                         'license_plate_confidence', 'mx1', 'my1', 'mx2', 'my2', 'license_plate_text'])

def put_text(frame, text, position, color=(0, 255, 0), font_scale=0.6, thickness=2, bg_color=(0, 0, 0)):
    """Helper function to put text with background on the frame."""
    text_size = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, font_scale, thickness)[0]
    text_x, text_y = position
    box_coords = ((text_x, text_y - text_size[1] - 5), (text_x + text_size[0] + 5, text_y + 5))
    cv2.rectangle(frame, box_coords[0], box_coords[1], bg_color, cv2.FILLED)
    cv2.putText(frame, text, position, cv2.FONT_HERSHEY_SIMPLEX, font_scale, color, thickness)

# %%
# Parameters 
video_path = 'C0142.mp4'  # Path to input video
model_path = 'yolo11n.pt'  # Path to YOLO model
license_plate_detector_model_path = 'runs/detect/license_plate_detector/weights/best.pt'  # Path to license plate detector model

output_video_path = 'output_video.mp4'  # Path to save the annotated output video
csv_file_path = 'detection_tracking_log.csv'  # Path to save the CSV log file
show_video = True  # Set to True to display the video while processing
classes_to_detect = [0, 1, 2, 3, 5]  # Class IDs to detect (e.g., [0, 2] for person and car)

model = initialize_model(model_path)
license_plate_detector = YOLO(license_plate_detector_model_path)
reader = initialize_reader()

# Define class names and colors for display
class_names = {
    0: "person",
    1: "bicycle",
    2: "car",
    3: "motorbike",
    5: "bus"
}
class_colors = {
    0: (255, 255, 255),
    1: (0, 255, 0),
    2: (0, 0, 255),
    3: (255, 255, 0),
    5: (0, 255, 255)
}

# Dictionary to store the best plate and its confidence for each track_id
vehicle_plates = {}

# Persistent total count of each class across all frames
total_class_count = Counter()
# Track unique IDs for each class to count only once
seen_ids = defaultdict(set)
frame_number = 0  # Initialize frame counter

blur_enabled = True # Set to True to blur faces
paused = False

# %%
# Open the video file and set up output for processed video
cap = cv2.VideoCapture(video_path)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec
fps = cap.get(cv2.CAP_PROP_FPS)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = initialize_video_writer(cap, output_video_path)
write_csv_header(csv_file_path)

# Loop through each frame
while cap.isOpened():
    if not paused:
        ret, frame = cap.read()
        if not ret:
            break

        start_time = time.time()
        frame_number += 1

        # Run YOLO detection and tracking
        results = model.track(frame, persist=True, classes=classes_to_detect)
        current_frame_count = Counter()

        # Process detections
        for result in results:
            boxes = result.boxes

            for box in boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                cls = int(box.cls[0])
                confidence = round(float(box.conf[0]), 2)

                if box.id is not None:
                    track_id = int(box.id[0].tolist())
                    if track_id not in seen_ids[cls]:
                        seen_ids[cls].add(track_id)
                        total_class_count[class_names[cls]] += 1

                    # License plate recognition for cars
                    license_plate_text = ""
                    plate_confidence = None
                    mx1, my1, mx2, my2 = None, None, None, None

                    # Check if the detected object is a car, then detect license plate within its bounding box
                    if class_names[cls] in ["car", "motorbike", "bus"]:
                        vehicle_img = frame[y1:y2, x1:x2]  # Crop the vehicle area to search for license plate
                        
                        # Check if the cropped image is large enough for license plate detection
                        min_plate_size = 80
                        if vehicle_img.shape[0] < min_plate_size or vehicle_img.shape[1] < min_plate_size:
                            continue
                        
                        # Check if the confidence is high enough for license plate detection
                        if confidence < 0.7:
                            continue
                        
                        # Run license plate detector model on the cropped vehicle image
                        plate_results = license_plate_detector.predict(vehicle_img)

                        # Process license plate detection results
                        if plate_results and len(plate_results[0].boxes) > 0:
                            for plate_box in plate_results[0].boxes:
                                # Get bounding box coordinates for the license plate, adjusted to the frame's coordinates
                                px1, py1, px2, py2 = map(int, plate_box.xyxy[0])
                                px1, py1, px2, py2 = px1 + x1, py1 + y1, px2 + x1, py2 + y1  # Adjust to the car's bounding box position
                                                            
                                # Draw bounding box for license plate
                                background_color = (255, 255, 255)  # White background for contrast
                                cv2.rectangle(frame, (px1, py1), (px2, py2), background_color, 2)
                                    
                                # Extract the license plate text using OCR
                                license_plate_roi = frame[py1:py2, px1:px2]
                                
                                # Resize based on the plate size
                                plate_height, plate_width = license_plate_roi.shape[:2]
                                scale_factor = 100.0 / plate_height
                                resized_plate = cv2.resize(
                                    license_plate_roi, None, fx=scale_factor, fy=scale_factor,
                                    interpolation=cv2.INTER_CUBIC)

                                # Convert to grayscale
                                gray_plate = cv2.cvtColor(resized_plate, cv2.COLOR_BGR2GRAY)

                                # Apply CLAHE
                                clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
                                equalized_plate = clahe.apply(gray_plate)

                                # Denoise the image
                                denoised_plate = cv2.fastNlMeansDenoising(equalized_plate, None, 10, 7, 21)

                                # Adaptive thresholding with adjusted parameters
                                thresh_plate = cv2.adaptiveThreshold(
                                    denoised_plate, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                    cv2.THRESH_BINARY_INV, 11, 2)

                                # Morphological operations
                                kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
                                morph_plate = cv2.morphologyEx(thresh_plate, cv2.MORPH_CLOSE, kernel)
                                morph_plate = cv2.morphologyEx(morph_plate, cv2.MORPH_OPEN, kernel)
                                morph_plate = cv2.bitwise_not(morph_plate)

                                plate_ocr_results = reader.readtext(morph_plate, allowlist='0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZ')
                                
                                if plate_ocr_results:
                                    license_plate_text = plate_ocr_results[0][-2]
                                    plate_confidence = round(plate_ocr_results[0][-1], 2)
                                    
                                    # Check if confidence is above threshold
                                    if plate_confidence >= 0.2:
                                        # Update the vehicle_plates dictionary
                                        if (track_id not in vehicle_plates) or (plate_confidence > vehicle_plates[track_id]['confidence']):
                                            vehicle_plates[track_id] = {
                                                'plate': license_plate_text,
                                                'confidence': plate_confidence
                                            }
                                            # Save the processed license plate image in /plates folder
                                            cv2.imwrite(f'plates/{frame_number}_{track_id}_{license_plate_text}.png', morph_plate)

                                        # Save coordinates for CSV logging
                                        mx1, my1, mx2, my2 = px1, py1, px2, py2
                                    
                                assigned_plate = vehicle_plates.get(track_id, None)
                                if assigned_plate:
                                    # Draw the assigned plate on the frame
                                    background_color = (255, 255, 255)  # White background for contrast
                                    high_contrast_color = (0, 0, 0)  # Black text
                                    put_text(frame, f"Plate: {assigned_plate['plate']}", (x1, y2 + 40), color=high_contrast_color, bg_color=background_color)

                                    # Update license_plate_text and plate_confidence for CSV logging
                                    license_plate_text = assigned_plate['plate']
                                    plate_confidence = assigned_plate['confidence']
                                else:
                                    # If no plate assigned yet, set to empty
                                    license_plate_text = ""
                                    plate_confidence = None
                    
                    # Draw bounding box and label for the detected object
                    color = class_colors.get(cls, (0, 0, 0))
                    cv2.rectangle(frame, (x1, y1), (x2, y2), color, 3)
                    put_text(frame, f"{class_names[cls]} {confidence}", (x1, y1 - 10), color=color)
                    put_text(frame, f"ID: {track_id}", (x1, y2 + 20), color=color)
                                    
                    # Anonimización condicional de personas
                    if class_names[cls] == "person" and blur_enabled:
                        person_roi = frame[y1:y2, x1:x2]
                        blurred_person = cv2.GaussianBlur(person_roi, (51, 51), 30)
                        frame[y1:y2, x1:x2] = blurred_person
                        
                    # Write to CSV
                    with open(csv_file_path, mode='a', newline='') as file:
                        writer = csv.writer(file)
                        writer.writerow([frame_number, class_names[cls], confidence, track_id, x1, y1, x2, y2,
                                        plate_confidence, mx1, my1, mx2, my2, license_plate_text])

                    current_frame_count[class_names[cls]] += 1

        # Display counts and FPS
        y_offset = 30
        for cls, count in total_class_count.items():
            put_text(frame, f"Total {cls}: {count}", (10, y_offset))
            y_offset += 20

        for cls, count in current_frame_count.items():
            put_text(frame, f"Frame {cls}: {count}", (10, y_offset), color=(255, 255, 255))
            y_offset += 20

        fps_calc = 1.0 / (time.time() - start_time)
        put_text(frame, f"FPS: {fps_calc:.2f}", (10, y_offset), color=(255, 255, 255))

        # Write frame to output video
        out.write(frame)

    # Optionally display the frame
    if show_video:
        cv2.imshow('Detection and Tracking', frame)
        key = cv2.waitKey(1 if not paused else 0) & 0xFF
        if key == 27: # Tecla Esc
            break
        elif key == ord(' '):  # Tecla Espacio
            paused = not paused
        elif key == ord('b'):  # Tecla para alternar desenfoque
            blur_enabled = not blur_enabled  # Cambia el estado de desenfoque
            print(f"Desenfoque {'habilitado' if blur_enabled else 'deshabilitado'}")
        
# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 car, 1 bus, 49.4ms
# Speed: 2.5ms preprocess, 49.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 1 Licenseplate, 62.2ms
# Speed: 2.0ms preprocess, 62.2ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 36.0ms
# Speed: 1.8ms preprocess, 36.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 49.8ms
# Speed: 1.5ms preprocess, 49.8ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 63.2ms
# Speed: 1.9ms preprocess, 63.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 55.7ms
# Speed: 2.0ms preprocess, 55.7ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 44.3ms
# Speed: 1.5ms preprocess, 44.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 51.2ms
# Speed: 1.8ms preprocess, 51.2ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 36.6ms
# Speed: 1.8ms preprocess, 36.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 45.7ms
# Speed: 1.5ms preprocess, 45.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 40.5ms
# Speed: 1.6ms preprocess, 40.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 41.0ms
# Speed: 1.4ms preprocess, 41.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
# 2024-11-06 20:10:06.990 python[66752:63548878] +[IMKClient subclass]: chose IMKClient_Legacy
# 2024-11-06 20:10:06.990 python[66752:63548878] +[IMKInputSession subclass]: chose IMKInputSession_Legacy
# 0: 384x640 1 car, 1 bus, 45.7ms
# Speed: 2.0ms preprocess, 45.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 90.0ms
# Speed: 4.9ms preprocess, 90.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 43.6ms
# Speed: 2.0ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 138.1ms
# Speed: 1.7ms preprocess, 138.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 54.3ms
# Speed: 2.0ms preprocess, 54.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 (no detections), 71.4ms
# Speed: 1.8ms preprocess, 71.4ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 111.0ms
# Speed: 13.4ms preprocess, 111.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 70.2ms
# Speed: 1.9ms preprocess, 70.2ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 50.6ms
# Speed: 3.5ms preprocess, 50.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 69.7ms
# Speed: 1.3ms preprocess, 69.7ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 139.7ms
# Speed: 1.7ms preprocess, 139.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 79.1ms
# Speed: 1.5ms preprocess, 79.1ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 109.2ms
# Speed: 2.6ms preprocess, 109.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 89.3ms
# Speed: 1.5ms preprocess, 89.3ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 104.6ms
# Speed: 1.7ms preprocess, 104.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 109.9ms
# Speed: 1.7ms preprocess, 109.9ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 92.9ms
# Speed: 1.9ms preprocess, 92.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 87.8ms
# Speed: 1.9ms preprocess, 87.8ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 41.0ms
# Speed: 1.6ms preprocess, 41.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 41.3ms
# Speed: 1.5ms preprocess, 41.3ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 43.2ms
# Speed: 1.6ms preprocess, 43.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 49.5ms
# Speed: 1.8ms preprocess, 49.5ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 32.0ms
# Speed: 7.5ms preprocess, 32.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 35.7ms
# Speed: 1.3ms preprocess, 35.7ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 54.7ms
# Speed: 2.7ms preprocess, 54.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 Licenseplate, 51.5ms
# Speed: 2.2ms preprocess, 51.5ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 49.6ms
# Speed: 1.5ms preprocess, 49.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 Licenseplate, 66.1ms
# Speed: 1.3ms preprocess, 66.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 49.3ms
# Speed: 36.8ms preprocess, 49.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 Licenseplate, 45.4ms
# Speed: 1.6ms preprocess, 45.4ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 62.2ms
# Speed: 2.0ms preprocess, 62.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 Licenseplate, 54.1ms
# Speed: 2.6ms preprocess, 54.1ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
# 2024-11-06 20:10:11.382 python[66752:63548878] _TIPropertyValueIsValid called with 16 on nil context!
# 2024-11-06 20:10:11.382 python[66752:63548878] imkxpc_getApplicationProperty:reply: called with incorrect property value 16, bailing.
# 2024-11-06 20:10:11.382 python[66752:63548878] Text input context does not respond to _valueForTIProperty:
# 0: 384x640 1 car, 1 bus, 37.1ms
# Speed: 1.5ms preprocess, 37.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 123.8ms
# Speed: 1.4ms preprocess, 123.8ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 55.3ms
# Speed: 3.1ms preprocess, 55.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 1 Licenseplate, 58.2ms
# Speed: 1.7ms preprocess, 58.2ms inference, 0.4ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 car, 1 bus, 40.9ms
# Speed: 1.4ms preprocess, 40.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 1 Licenseplate, 45.5ms
# Speed: 1.3ms preprocess, 45.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 54.5ms
# Speed: 1.7ms preprocess, 54.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 56.7ms
# Speed: 1.7ms preprocess, 56.7ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 car, 1 bus, 61.9ms
# Speed: 4.5ms preprocess, 61.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 49.4ms
# Speed: 1.5ms preprocess, 49.4ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 39.7ms
# Speed: 1.5ms preprocess, 39.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 45.6ms
# Speed: 1.5ms preprocess, 45.6ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 61.4ms
# Speed: 1.6ms preprocess, 61.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 73.2ms
# Speed: 1.5ms preprocess, 73.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 52.6ms
# Speed: 3.7ms preprocess, 52.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 112.0ms
# Speed: 1.4ms preprocess, 112.0ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 54.3ms
# Speed: 2.2ms preprocess, 54.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 70.3ms
# Speed: 6.7ms preprocess, 70.3ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 47.7ms
# Speed: 1.6ms preprocess, 47.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 68.6ms
# Speed: 1.7ms preprocess, 68.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 49.7ms
# Speed: 1.7ms preprocess, 49.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 67.0ms
# Speed: 1.4ms preprocess, 67.0ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 49.8ms
# Speed: 1.7ms preprocess, 49.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 83.3ms
# Speed: 1.5ms preprocess, 83.3ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 70.5ms
# Speed: 5.5ms preprocess, 70.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 50.3ms
# Speed: 1.5ms preprocess, 50.3ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 57.7ms
# Speed: 2.1ms preprocess, 57.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 1 Licenseplate, 69.9ms
# Speed: 1.7ms preprocess, 69.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 43.8ms
# Speed: 1.8ms preprocess, 43.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 94.4ms
# Speed: 1.3ms preprocess, 94.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 car, 1 bus, 47.4ms
# Speed: 2.4ms preprocess, 47.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 72.7ms
# Speed: 2.0ms preprocess, 72.7ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 68.2ms
# Speed: 1.6ms preprocess, 68.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 57.0ms
# Speed: 2.2ms preprocess, 57.0ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 52.9ms
# Speed: 1.7ms preprocess, 52.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 80.5ms
# Speed: 1.7ms preprocess, 80.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 59.6ms
# Speed: 2.2ms preprocess, 59.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 74.5ms
# Speed: 1.6ms preprocess, 74.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 89.9ms
# Speed: 2.0ms preprocess, 89.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 60.8ms
# Speed: 14.7ms preprocess, 60.8ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 93.8ms
# Speed: 2.0ms preprocess, 93.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 57.2ms
# Speed: 1.6ms preprocess, 57.2ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 36.7ms
# Speed: 1.6ms preprocess, 36.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 49.8ms
# Speed: 1.9ms preprocess, 49.8ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 53.9ms
# Speed: 3.0ms preprocess, 53.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 60.0ms
# Speed: 1.5ms preprocess, 60.0ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 50.8ms
# Speed: 9.6ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 1 Licenseplate, 60.9ms
# Speed: 1.5ms preprocess, 60.9ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 47.2ms
# Speed: 1.6ms preprocess, 47.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 85.9ms
# Speed: 2.8ms preprocess, 85.9ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 35.0ms
# Speed: 1.6ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 47.0ms
# Speed: 1.5ms preprocess, 47.0ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 47.4ms
# Speed: 1.7ms preprocess, 47.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 61.6ms
# Speed: 1.8ms preprocess, 61.6ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 53.1ms
# Speed: 1.5ms preprocess, 53.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 1 Licenseplate, 76.2ms
# Speed: 1.3ms preprocess, 76.2ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 54.9ms
# Speed: 1.6ms preprocess, 54.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 66.8ms
# Speed: 1.4ms preprocess, 66.8ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 car, 1 bus, 62.4ms
# Speed: 1.7ms preprocess, 62.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 73.0ms
# Speed: 1.7ms preprocess, 73.0ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 122.3ms
# Speed: 1.5ms preprocess, 122.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 59.9ms
# Speed: 1.8ms preprocess, 59.9ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 49.4ms
# Speed: 4.1ms preprocess, 49.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 63.1ms
# Speed: 1.5ms preprocess, 63.1ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 65.2ms
# Speed: 1.4ms preprocess, 65.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 1 Licenseplate, 93.4ms
# Speed: 1.7ms preprocess, 93.4ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 43.2ms
# Speed: 1.6ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 46.0ms
# Speed: 1.5ms preprocess, 46.0ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 54.8ms
# Speed: 1.5ms preprocess, 54.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 94.2ms
# Speed: 2.6ms preprocess, 94.2ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 43.0ms
# Speed: 1.5ms preprocess, 43.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 49.3ms
# Speed: 1.3ms preprocess, 49.3ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 45.4ms
# Speed: 1.6ms preprocess, 45.4ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 68.2ms
# Speed: 1.6ms preprocess, 68.2ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 60.3ms
# Speed: 1.6ms preprocess, 60.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 71.4ms
# Speed: 1.7ms preprocess, 71.4ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 1 car, 1 bus, 35.2ms
# Speed: 1.4ms preprocess, 35.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 62.7ms
# Speed: 1.7ms preprocess, 62.7ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 43.3ms
# Speed: 1.7ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 62.9ms
# Speed: 1.5ms preprocess, 62.9ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 64.4ms
# Speed: 1.6ms preprocess, 64.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 117.2ms
# Speed: 2.0ms preprocess, 117.2ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 38.8ms
# Speed: 1.6ms preprocess, 38.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 81.9ms
# Speed: 1.4ms preprocess, 81.9ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 38.7ms
# Speed: 1.7ms preprocess, 38.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 74.6ms
# Speed: 1.7ms preprocess, 74.6ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 73.1ms
# Speed: 1.9ms preprocess, 73.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 71.6ms
# Speed: 1.4ms preprocess, 71.6ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 53.0ms
# Speed: 1.5ms preprocess, 53.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 56.5ms
# Speed: 1.5ms preprocess, 56.5ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 87.6ms
# Speed: 1.8ms preprocess, 87.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 62.8ms
# Speed: 1.7ms preprocess, 62.8ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 53.0ms
# Speed: 2.3ms preprocess, 53.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 61.1ms
# Speed: 3.8ms preprocess, 61.1ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 49.5ms
# Speed: 1.5ms preprocess, 49.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 67.6ms
# Speed: 1.7ms preprocess, 67.6ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 51.0ms
# Speed: 1.5ms preprocess, 51.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 76.1ms
# Speed: 2.7ms preprocess, 76.1ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 64.9ms
# Speed: 1.6ms preprocess, 64.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 57.0ms
# Speed: 1.8ms preprocess, 57.0ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 58.0ms
# Speed: 1.6ms preprocess, 58.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 84.4ms
# Speed: 1.5ms preprocess, 84.4ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 82.6ms
# Speed: 2.7ms preprocess, 82.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 102.7ms
# Speed: 4.0ms preprocess, 102.7ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 48.7ms
# Speed: 1.7ms preprocess, 48.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 60.3ms
# Speed: 1.9ms preprocess, 60.3ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 83.2ms
# Speed: 3.2ms preprocess, 83.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 72.1ms
# Speed: 1.5ms preprocess, 72.1ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 78.6ms
# Speed: 1.6ms preprocess, 78.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 66.6ms
# Speed: 1.7ms preprocess, 66.6ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 car, 1 bus, 50.7ms
# Speed: 1.7ms preprocess, 50.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 48.8ms
# Speed: 1.5ms preprocess, 48.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 46.3ms
# Speed: 1.5ms preprocess, 46.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 50.0ms
# Speed: 2.6ms preprocess, 50.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 96.8ms
# Speed: 5.3ms preprocess, 96.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 car, 1 bus, 57.5ms
# Speed: 1.6ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 90.3ms
# Speed: 1.5ms preprocess, 90.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 car, 1 bus, 47.9ms
# Speed: 1.5ms preprocess, 47.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 66.4ms
# Speed: 1.6ms preprocess, 66.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 car, 1 bus, 82.6ms
# Speed: 1.6ms preprocess, 82.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 58.8ms
# Speed: 1.8ms preprocess, 58.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 car, 1 bus, 45.0ms
# Speed: 1.4ms preprocess, 45.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 78.4ms
# Speed: 6.8ms preprocess, 78.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 car, 1 bus, 54.2ms
# Speed: 3.0ms preprocess, 54.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 56.1ms
# Speed: 1.6ms preprocess, 56.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 56.9ms
# Speed: 2.2ms preprocess, 56.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 44.9ms
# Speed: 1.7ms preprocess, 44.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 61.0ms
# Speed: 2.2ms preprocess, 61.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 42.2ms
# Speed: 2.1ms preprocess, 42.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 51.6ms
# Speed: 4.7ms preprocess, 51.6ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 59.0ms
# Speed: 1.7ms preprocess, 59.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 170.0ms
# Speed: 2.3ms preprocess, 170.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 122.0ms
# Speed: 3.4ms preprocess, 122.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 car, 100.6ms
# Speed: 2.5ms preprocess, 100.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 99.0ms
# Speed: 1.6ms preprocess, 99.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 57.5ms
# Speed: 5.6ms preprocess, 57.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 43.5ms
# Speed: 1.4ms preprocess, 43.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 60.1ms
# Speed: 1.5ms preprocess, 60.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 48.6ms
# Speed: 1.5ms preprocess, 48.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 69.8ms
# Speed: 1.6ms preprocess, 69.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 49.4ms
# Speed: 1.5ms preprocess, 49.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 67.6ms
# Speed: 1.9ms preprocess, 67.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 65.2ms
# Speed: 4.8ms preprocess, 65.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 47.4ms
# Speed: 1.5ms preprocess, 47.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 63.6ms
# Speed: 1.8ms preprocess, 63.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 44.4ms
# Speed: 2.1ms preprocess, 44.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 117.6ms
# Speed: 1.6ms preprocess, 117.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 41.2ms
# Speed: 1.6ms preprocess, 41.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 50.3ms
# Speed: 2.0ms preprocess, 50.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 65.5ms
# Speed: 3.5ms preprocess, 65.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 53.6ms
# Speed: 1.5ms preprocess, 53.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 66.7ms
# Speed: 1.5ms preprocess, 66.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 45.3ms
# Speed: 1.6ms preprocess, 45.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 60.6ms
# Speed: 1.4ms preprocess, 60.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 52.7ms
# Speed: 1.9ms preprocess, 52.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 82.1ms
# Speed: 2.3ms preprocess, 82.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 53.3ms
# Speed: 1.6ms preprocess, 53.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 82.5ms
# Speed: 1.8ms preprocess, 82.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 55.0ms
# Speed: 1.5ms preprocess, 55.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 57.6ms
# Speed: 1.9ms preprocess, 57.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 61.5ms
# Speed: 1.5ms preprocess, 61.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 56.6ms
# Speed: 11.4ms preprocess, 56.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 50.6ms
# Speed: 1.9ms preprocess, 50.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 72.8ms
# Speed: 5.5ms preprocess, 72.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 65.0ms
# Speed: 2.4ms preprocess, 65.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 43.3ms
# Speed: 2.1ms preprocess, 43.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 66.1ms
# Speed: 1.7ms preprocess, 66.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 50.4ms
# Speed: 6.6ms preprocess, 50.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 47.1ms
# Speed: 11.4ms preprocess, 47.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 88.6ms
# Speed: 2.3ms preprocess, 88.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 92.0ms
# Speed: 1.5ms preprocess, 92.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 50.4ms
# Speed: 1.8ms preprocess, 50.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 55.6ms
# Speed: 1.6ms preprocess, 55.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 79.7ms
# Speed: 9.7ms preprocess, 79.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 37.8ms
# Speed: 1.6ms preprocess, 37.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 62.8ms
# Speed: 1.6ms preprocess, 62.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 52.6ms
# Speed: 2.8ms preprocess, 52.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 65.8ms
# Speed: 1.6ms preprocess, 65.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 56.1ms
# Speed: 1.6ms preprocess, 56.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 72.0ms
# Speed: 1.7ms preprocess, 72.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 53.9ms
# Speed: 2.0ms preprocess, 53.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 40.2ms
# Speed: 1.9ms preprocess, 40.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 58.6ms
# Speed: 1.5ms preprocess, 58.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 53.7ms
# Speed: 4.0ms preprocess, 53.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 83.4ms
# Speed: 3.2ms preprocess, 83.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 43.2ms
# Speed: 2.1ms preprocess, 43.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 71.4ms
# Speed: 3.4ms preprocess, 71.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 61.0ms
# Speed: 1.5ms preprocess, 61.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 85.7ms
# Speed: 1.4ms preprocess, 85.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 51.0ms
# Speed: 1.9ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 91.5ms
# Speed: 5.5ms preprocess, 91.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 95.2ms
# Speed: 5.9ms preprocess, 95.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 70.3ms
# Speed: 2.4ms preprocess, 70.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 63.9ms
# Speed: 1.6ms preprocess, 63.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 62.0ms
# Speed: 1.4ms preprocess, 62.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 58.0ms
# Speed: 1.7ms preprocess, 58.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 64.3ms
# Speed: 1.7ms preprocess, 64.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 60.8ms
# Speed: 1.8ms preprocess, 60.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 60.9ms
# Speed: 3.8ms preprocess, 60.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 59.0ms
# Speed: 1.6ms preprocess, 59.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 102.5ms
# Speed: 8.0ms preprocess, 102.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 53.6ms
# Speed: 2.0ms preprocess, 53.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 75.1ms
# Speed: 5.8ms preprocess, 75.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 73.0ms
# Speed: 3.4ms preprocess, 73.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 63.9ms
# Speed: 1.9ms preprocess, 63.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 84.2ms
# Speed: 2.3ms preprocess, 84.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 61.0ms
# Speed: 2.7ms preprocess, 61.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 160.4ms
# Speed: 2.6ms preprocess, 160.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 37.7ms
# Speed: 1.5ms preprocess, 37.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 68.3ms
# Speed: 1.6ms preprocess, 68.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 45.2ms
# Speed: 1.7ms preprocess, 45.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 66.7ms
# Speed: 1.6ms preprocess, 66.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 41.1ms
# Speed: 1.7ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 62.6ms
# Speed: 1.8ms preprocess, 62.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 51.0ms
# Speed: 2.8ms preprocess, 51.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 115.0ms
# Speed: 1.6ms preprocess, 115.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 34.4ms
# Speed: 1.6ms preprocess, 34.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 99.9ms
# Speed: 1.3ms preprocess, 99.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 car, 1 bus, 63.4ms
# Speed: 1.6ms preprocess, 63.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 101.0ms
# Speed: 1.3ms preprocess, 101.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 36.9ms
# Speed: 2.0ms preprocess, 36.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 83.1ms
# Speed: 1.6ms preprocess, 83.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 52.0ms
# Speed: 3.6ms preprocess, 52.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 75.9ms
# Speed: 1.7ms preprocess, 75.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 47.7ms
# Speed: 2.0ms preprocess, 47.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 67.6ms
# Speed: 1.3ms preprocess, 67.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 55.8ms
# Speed: 1.9ms preprocess, 55.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 83.8ms
# Speed: 5.4ms preprocess, 83.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 87.4ms
# Speed: 1.5ms preprocess, 87.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 59.9ms
# Speed: 2.4ms preprocess, 59.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 43.6ms
# Speed: 1.9ms preprocess, 43.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 88.1ms
# Speed: 1.4ms preprocess, 88.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 63.3ms
# Speed: 1.7ms preprocess, 63.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 84.6ms
# Speed: 7.5ms preprocess, 84.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 61.7ms
# Speed: 2.8ms preprocess, 61.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 90.8ms
# Speed: 2.4ms preprocess, 90.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 56.3ms
# Speed: 1.6ms preprocess, 56.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 77.5ms
# Speed: 1.5ms preprocess, 77.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 86.4ms
# Speed: 1.5ms preprocess, 86.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 65.7ms
# Speed: 1.3ms preprocess, 65.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 53.0ms
# Speed: 1.7ms preprocess, 53.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 69.3ms
# Speed: 1.6ms preprocess, 69.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 67.8ms
# Speed: 1.4ms preprocess, 67.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 106.7ms
# Speed: 1.5ms preprocess, 106.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 71.5ms
# Speed: 1.6ms preprocess, 71.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 80.4ms
# Speed: 1.6ms preprocess, 80.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 69.2ms
# Speed: 3.2ms preprocess, 69.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 73.5ms
# Speed: 2.1ms preprocess, 73.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 70.5ms
# Speed: 1.6ms preprocess, 70.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 84.0ms
# Speed: 1.4ms preprocess, 84.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 55.4ms
# Speed: 1.7ms preprocess, 55.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 69.3ms
# Speed: 1.5ms preprocess, 69.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 60.2ms
# Speed: 1.5ms preprocess, 60.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 77.6ms
# Speed: 1.4ms preprocess, 77.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 53.9ms
# Speed: 1.6ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 101.9ms
# Speed: 1.4ms preprocess, 101.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 62.3ms
# Speed: 7.3ms preprocess, 62.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 122.4ms
# Speed: 2.5ms preprocess, 122.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 98.1ms
# Speed: 1.6ms preprocess, 98.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 148.4ms
# Speed: 4.0ms preprocess, 148.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 43.9ms
# Speed: 1.6ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 36.5ms
# Speed: 1.9ms preprocess, 36.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 103.7ms
# Speed: 8.3ms preprocess, 103.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 71.5ms
# Speed: 1.7ms preprocess, 71.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 63.3ms
# Speed: 2.1ms preprocess, 63.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 82.0ms
# Speed: 1.4ms preprocess, 82.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 48.2ms
# Speed: 1.5ms preprocess, 48.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 102.2ms
# Speed: 2.1ms preprocess, 102.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 51.2ms
# Speed: 1.8ms preprocess, 51.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 79.2ms
# Speed: 2.5ms preprocess, 79.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 65.0ms
# Speed: 2.1ms preprocess, 65.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 63.2ms
# Speed: 1.5ms preprocess, 63.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 83.2ms
# Speed: 2.7ms preprocess, 83.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 74.9ms
# Speed: 1.5ms preprocess, 74.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 53.6ms
# Speed: 4.8ms preprocess, 53.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 64.3ms
# Speed: 1.5ms preprocess, 64.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 44.3ms
# Speed: 2.1ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 43.9ms
# Speed: 1.8ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 53.6ms
# Speed: 2.2ms preprocess, 53.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 49.8ms
# Speed: 1.6ms preprocess, 49.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 41.4ms
# Speed: 1.7ms preprocess, 41.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 58.2ms
# Speed: 1.6ms preprocess, 58.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 57.6ms
# Speed: 1.5ms preprocess, 57.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 90.9ms
# Speed: 30.7ms preprocess, 90.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 60.5ms
# Speed: 2.9ms preprocess, 60.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 115.3ms
# Speed: 2.2ms preprocess, 115.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 48.6ms
# Speed: 1.5ms preprocess, 48.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 44.0ms
# Speed: 1.4ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 58.0ms
# Speed: 1.6ms preprocess, 58.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 38.9ms
# Speed: 1.6ms preprocess, 38.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 45.9ms
# Speed: 1.6ms preprocess, 45.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 50.5ms
# Speed: 1.7ms preprocess, 50.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 60.8ms
# Speed: 1.7ms preprocess, 60.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 109.6ms
# Speed: 1.8ms preprocess, 109.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 55.6ms
# Speed: 2.1ms preprocess, 55.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 68.6ms
# Speed: 2.5ms preprocess, 68.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 55.6ms
# Speed: 1.7ms preprocess, 55.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 64.0ms
# Speed: 1.9ms preprocess, 64.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 49.7ms
# Speed: 2.0ms preprocess, 49.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 52.5ms
# Speed: 4.6ms preprocess, 52.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 46.5ms
# Speed: 4.5ms preprocess, 46.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 61.5ms
# Speed: 4.4ms preprocess, 61.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 100.6ms
# Speed: 1.6ms preprocess, 100.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 116.2ms
# Speed: 1.5ms preprocess, 116.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 90.4ms
# Speed: 1.7ms preprocess, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 70.2ms
# ...
#
# 0: 384x640 1 person, 4 cars, 30.7ms
# Speed: 2.9ms preprocess, 30.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 (no detections), 35.8ms
# Speed: 3.7ms preprocess, 35.8ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 person, 4 cars, 45.8ms
# Speed: 1.7ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 (no detections), 33.7ms
# Speed: 0.9ms preprocess, 33.7ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 person, 4 cars, 44.1ms
# Speed: 2.9ms preprocess, 44.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 (no detections), 30.1ms
# Speed: 1.0ms preprocess, 30.1ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 person, 4 cars, 40.5ms
# Speed: 3.0ms preprocess, 40.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 (no detections), 65.1ms
# Speed: 2.3ms preprocess, 65.1ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 1 person, 4 cars, 49.4ms
# Speed: 10.1ms preprocess, 49.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 81.5ms
# Speed: 1.3ms preprocess, 81.5ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 person, 4 cars, 36.9ms
# Speed: 2.2ms preprocess, 36.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 1 person, 4 cars, 40.0ms
# Speed: 1.6ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 55.4ms
# Speed: 1.0ms preprocess, 55.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 person, 4 cars, 40.1ms
# Speed: 1.8ms preprocess, 40.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 31.9ms
# Speed: 1.0ms preprocess, 31.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 person, 4 cars, 61.5ms
# Speed: 11.1ms preprocess, 61.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 55.3ms
# Speed: 1.0ms preprocess, 55.3ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 person, 4 cars, 35.4ms
# Speed: 1.8ms preprocess, 35.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 480x640 (no detections), 33.9ms
# Speed: 1.0ms preprocess, 33.9ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 person, 4 cars, 72.2ms
# Speed: 1.8ms preprocess, 72.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 (no detections), 59.2ms
# Speed: 1.8ms preprocess, 59.2ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 person, 4 cars, 45.8ms
# Speed: 1.6ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 (no detections), 63.6ms
# Speed: 4.0ms preprocess, 63.6ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 person, 3 cars, 107.3ms
# Speed: 3.7ms preprocess, 107.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 (no detections), 36.8ms
# Speed: 1.2ms preprocess, 36.8ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 person, 3 cars, 47.1ms
# Speed: 1.4ms preprocess, 47.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 (no detections), 36.8ms
# Speed: 0.9ms preprocess, 36.8ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 3 cars, 28.6ms
# Speed: 3.0ms preprocess, 28.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 (no detections), 37.4ms
# Speed: 1.9ms preprocess, 37.4ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 3 cars, 30.6ms
# Speed: 4.8ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 (no detections), 38.4ms
# Speed: 1.4ms preprocess, 38.4ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 3 cars, 44.8ms
# Speed: 3.0ms preprocess, 44.8ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 448x640 (no detections), 39.9ms
# Speed: 1.5ms preprocess, 39.9ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 3 cars, 45.2ms
# Speed: 1.3ms preprocess, 45.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 (no detections), 77.3ms
# Speed: 7.4ms preprocess, 77.3ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 3 cars, 34.3ms
# Speed: 1.7ms preprocess, 34.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 416x640 (no detections), 33.4ms
# Speed: 1.3ms preprocess, 33.4ms inference, 0.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 3 cars, 31.2ms
# Speed: 1.7ms preprocess, 31.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 30.4ms
# Speed: 1.6ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 27.0ms
# Speed: 4.1ms preprocess, 27.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 33.9ms
# Speed: 1.6ms preprocess, 33.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 47.3ms
# Speed: 4.1ms preprocess, 47.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 40.4ms
# Speed: 1.4ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 50.3ms
# Speed: 1.6ms preprocess, 50.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 31.3ms
# Speed: 1.4ms preprocess, 31.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 31.2ms
# Speed: 1.7ms preprocess, 31.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 32.2ms
# Speed: 1.4ms preprocess, 32.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 82.6ms
# Speed: 6.5ms preprocess, 82.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 80.2ms
# Speed: 1.6ms preprocess, 80.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 59.2ms
# Speed: 1.6ms preprocess, 59.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 95.9ms
# Speed: 1.7ms preprocess, 95.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 46.6ms
# Speed: 5.2ms preprocess, 46.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.5ms
# Speed: 8.7ms preprocess, 45.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 30.6ms
# Speed: 1.5ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 47.8ms
# Speed: 1.5ms preprocess, 47.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 51.6ms
# Speed: 1.6ms preprocess, 51.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 32.6ms
# Speed: 1.6ms preprocess, 32.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 53.3ms
# Speed: 1.7ms preprocess, 53.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 29.0ms
# Speed: 1.4ms preprocess, 29.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 33.0ms
# Speed: 1.5ms preprocess, 33.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 33.7ms
# Speed: 1.7ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 47.1ms
# Speed: 7.6ms preprocess, 47.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 28.5ms
# Speed: 1.5ms preprocess, 28.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 52.8ms
# Speed: 1.6ms preprocess, 52.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 30.6ms
# Speed: 1.5ms preprocess, 30.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 31.0ms
# Speed: 1.4ms preprocess, 31.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 66.8ms
# Speed: 3.4ms preprocess, 66.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 30.5ms
# Speed: 2.5ms preprocess, 30.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 28.8ms
# Speed: 1.6ms preprocess, 28.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 35.9ms
# Speed: 1.5ms preprocess, 35.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 33.5ms
# Speed: 1.4ms preprocess, 33.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 65.7ms
# Speed: 7.0ms preprocess, 65.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 33.0ms
# Speed: 1.7ms preprocess, 33.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 32.5ms
# Speed: 1.6ms preprocess, 32.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 28.1ms
# Speed: 1.5ms preprocess, 28.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 29.9ms
# Speed: 1.7ms preprocess, 29.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 31.3ms
# Speed: 1.4ms preprocess, 31.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 33.1ms
# Speed: 1.5ms preprocess, 33.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 45.0ms
# Speed: 1.6ms preprocess, 45.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 84.0ms
# Speed: 1.7ms preprocess, 84.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 36.6ms
# Speed: 1.7ms preprocess, 36.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 33.9ms
# Speed: 1.6ms preprocess, 33.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 27.9ms
# Speed: 3.6ms preprocess, 27.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 33.7ms
# Speed: 3.4ms preprocess, 33.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 30.9ms
# Speed: 1.6ms preprocess, 30.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 36.6ms
# Speed: 1.6ms preprocess, 36.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 32.4ms
# Speed: 1.6ms preprocess, 32.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 30.8ms
# Speed: 1.5ms preprocess, 30.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 40.2ms
# Speed: 7.1ms preprocess, 40.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 59.6ms
# Speed: 2.8ms preprocess, 59.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 34.1ms
# Speed: 3.1ms preprocess, 34.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 31.6ms
# Speed: 1.5ms preprocess, 31.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 30.0ms
# Speed: 2.2ms preprocess, 30.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 30.6ms
# Speed: 1.5ms preprocess, 30.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 30.3ms
# Speed: 1.5ms preprocess, 30.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 41.0ms
# Speed: 1.7ms preprocess, 41.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 34.5ms
# Speed: 1.8ms preprocess, 34.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 37.5ms
# Speed: 13.7ms preprocess, 37.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 54.2ms
# Speed: 1.8ms preprocess, 54.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 28.7ms
# Speed: 1.6ms preprocess, 28.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 30.0ms
# Speed: 1.7ms preprocess, 30.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 51.0ms
# Speed: 2.0ms preprocess, 51.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 48.3ms
# Speed: 1.8ms preprocess, 48.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 31.9ms
# Speed: 1.7ms preprocess, 31.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 33.5ms
# Speed: 1.6ms preprocess, 33.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 28.4ms
# Speed: 1.4ms preprocess, 28.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 31.6ms
# Speed: 1.5ms preprocess, 31.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 29.7ms
# Speed: 1.4ms preprocess, 29.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 31.9ms
# Speed: 1.7ms preprocess, 31.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 78.2ms
# Speed: 5.5ms preprocess, 78.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.7ms
# Speed: 1.9ms preprocess, 41.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 52.5ms
# Speed: 1.6ms preprocess, 52.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 50.2ms
# Speed: 1.7ms preprocess, 50.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 29.4ms
# Speed: 1.7ms preprocess, 29.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 27.0ms
# Speed: 1.5ms preprocess, 27.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 28.5ms
# Speed: 1.4ms preprocess, 28.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 32.5ms
# Speed: 1.5ms preprocess, 32.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 69.9ms
# Speed: 1.3ms preprocess, 69.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 29.4ms
# Speed: 1.5ms preprocess, 29.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 33.3ms
# Speed: 1.4ms preprocess, 33.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 29.3ms
# Speed: 2.0ms preprocess, 29.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 29.9ms
# Speed: 1.4ms preprocess, 29.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 30.4ms
# Speed: 1.6ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ### Resultados
#
# Esta sección se presentan los resultados obtenidos. Cargaremos el archivo CSV para revisar el recuento total de cada tipo de objeto detectado, así como los detalles de las detecciones de matrículas.

# %%
# Cargar el archivo CSV de resultados
import pandas as pd

results_df = pd.read_csv('detection_tracking_log.csv')
print("Resumen de detecciones por clase:")
print(results_df['object_type'].value_counts())

print("\nEjemplo de datos de detección de matrículas:")
display(results_df[results_df['object_type'] == 'car'].head())
# Out:
# Resumen de detecciones por clase:
# object_type
# person       2929
# car          2024
# bus           131
# bicycle        40
# motorbike      19
# Name: count, dtype: int64
#
# Ejemplo de datos de detección de matrículas:
#      frame object_type  confidence  tracking_id    x1   y1    x2   y2  \
# 618    392         car        0.78           13  1809  413  1919  548
# 622    393         car        0.79           13  1787  405  1919  541
# 626    394         car        0.79           13  1762  389  1919  541
# 630    395         car        0.84           13  1737  363  1919  538
# 634    396         car        0.87           13  1715  349  1919  535
#
#      license_plate_confidence  mx1  my1  mx2  my2 license_plate_text
# 618                       NaN  NaN  NaN  NaN  NaN                NaN
# 622                       NaN  NaN  NaN  NaN  NaN                NaN
# 626                       NaN  NaN  NaN  NaN  NaN                NaN
# 630                       NaN  NaN  NaN  NaN  NaN                NaN
# 634                       NaN  NaN  NaN  NaN  NaN                NaN

# %% [markdown]
# ## Conclusión
#
# En esta práctica se ha desarrollado un prototipo funcional que permite:
#
# - Detectar y seguir personas y vehículos en video.
# - Detectar y leer matrículas en vehículos mediante un modelo YOLO y OCR.
# - Exportar los resultados visuales en un video y los datos de detección en un archivo CSV.
#
# Este prototipo constituye una herramienta útil para el análisis automatizado de video en aplicaciones de monitoreo y seguridad, con posibilidad de mejoras futuras en el rendimiento y precisión del OCR de matrículas.
